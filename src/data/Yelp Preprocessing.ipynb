# %%
# !pip install flat-table

import pandas as pd
import json 
from pandas.io.json import json_normalize #package for flattening json in pandas df
import flat_table as ft #another package for flattening json in pandas df that also handles nulls nicely
import math
import numpy as np
# Out:
# Requirement already satisfied: flat-table in c:\users\galla\anaconda3\lib\site-packages (1.1.1)
# Requirement already satisfied: pandas in c:\users\galla\anaconda3\lib\site-packages (from flat-table) (1.1.1)
# Requirement already satisfied: numpy in c:\users\galla\anaconda3\lib\site-packages (from flat-table) (1.19.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\galla\anaconda3\lib\site-packages (from pandas->flat-table) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\galla\anaconda3\lib\site-packages (from pandas->flat-table) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\galla\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->flat-table) (1.15.0)

# %%
yelp = pd.read_json("yelp_academic_dataset_business.json", lines= True)
yelp.info()
yelp.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209393 entries, 0 to 209392
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   business_id   209393 non-null  object
#  1   name          209393 non-null  object
#  2   address       209393 non-null  object
#  3   city          209393 non-null  object
#  4   state         209393 non-null  object
#  5   postal_code   209393 non-null  object
#  6   latitude      209393 non-null  float64
#  7   longitude     209393 non-null  float64
#  8   stars         209393 non-null  float64
#  9   review_count  209393 non-null  int64
#  10  is_open       209393 non-null  int64
#  11  attributes    180348 non-null  object
#  12  categories    208869 non-null  object
#  13  hours         164550 non-null  object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 22.4+ MB
#               business_id                      name  \
# 0  f9NumwFMBDn751xgFiRbNA  The Range At Lake Norman
# 1  Yzvjg0SayhoZgCljUJRF9Q         Carlos Santo, NMD
# 2  XNoUzKckATkOD1hP6vghZg                   Felinus
# 3  6OAZjbxqM5ol29BuHsil3w      Nevada House of Hose
# 4  51M2Kk903DFYI6gnB5I6SQ   USE MY GUY SERVICES LLC
#
#                      address             city state postal_code   latitude  \
# 0            10913 Bailey Rd        Cornelius    NC       28031  35.462724
# 1  8880 E Via Linda, Ste 107       Scottsdale    AZ       85258  33.569404
# 2      3554 Rue Notre-Dame O         Montreal    QC     H4C 1P4  45.479984
# 3             1015 Sharp Cir  North Las Vegas    NV       89030  36.219728
# 4         4827 E Downing Cir             Mesa    AZ       85205  33.428065
#
#     longitude  stars  review_count  is_open  \
# 0  -80.852612    3.5            36        1
# 1 -111.890264    5.0             4        1
# 2  -73.580070    5.0             5        1
# 3 -115.127725    2.5             3        0
# 4 -111.726648    4.5            26        1
#
#                                           attributes  \
# 0  {'BusinessAcceptsCreditCards': 'True', 'BikePa...
# 1  {'GoodForKids': 'True', 'ByAppointmentOnly': '...
# 2                                               None
# 3  {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 4  {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
#
#                                           categories  \
# 0  Active Life, Gun/Rifle Ranges, Guns & Ammo, Sh...
# 1  Health & Medical, Fitness & Instruction, Yoga,...
# 2                   Pets, Pet Services, Pet Groomers
# 3  Hardware Stores, Home Services, Building Suppl...
# 4  Home Services, Plumbing, Electricians, Handyma...
#
#                                                hours
# 0  {'Monday': '10:0-18:0', 'Tuesday': '11:0-20:0'...
# 1                                               None
# 2                                               None
# 3  {'Monday': '7:0-16:0', 'Tuesday': '7:0-16:0', ...
# 4  {'Monday': '0:0-0:0', 'Tuesday': '9:0-16:0', '...

# %%
# ensure business_id is unique
yelp['business_id'].duplicated().sum()
# Out:
# 0

# %%
#Check for nulls
yelp.isna().sum()
# Out:
# business_id         0
# name                0
# address             0
# city                0
# state               0
# postal_code         0
# latitude            0
# longitude           0
# stars               0
# review_count        0
# is_open             0
# attributes      29045
# categories        524
# hours           44843
# dtype: int64

# %% [markdown]
# # Removing and Cleaning Data

# %% [markdown]
# Looking at the value counts of our business data per state, it is clear that our data is only representative of a few states.

# %%
yelp['state'].value_counts()
# Out:
# AZ     60803
# NV     39084
# ON     36627
# OH     16392
# NC     16218
# PA     12376
# QC     10233
# AB      8682
# WI      5525
# IL      2034
# SC      1328
# CA        23
# NY        22
# TX         6
# WA         5
# FL         3
# GA         3
# AL         3
# BC         2
# CO         2
# UT         2
# NE         2
# CT         2
# MI         2
# VT         2
# MO         1
# AR         1
# MB         1
# OR         1
# AK         1
# HI         1
# HPL        1
# YT         1
# DOW        1
# VA         1
# DUR        1
# XWY        1
# Name: state, dtype: int64

# %% [markdown]
# This is unfortunate, but there's nothing we can really do aside for looking for other similar datasets to combine with this one (which we tried, and unfortunately came up short). However, interestingly enough we have data from a lot of states where we only have at most a couple dozen businesses. While this might not seem like a problem, it can actually make things a bit misleading as we continue with the project. Since all of our queries for our business data involve taking aggregates, it is quite misleading to compare our Arizona aggregate (with 60803 businesses) with, say, our California aggregate (with 23 businesses). We could always mention the denominator on the app itself, but it does not seem like responsible data science to show our users data and hope they are savvy enough to read a disclaimer and not use it. It is more responsible, then, to simply not show business data about states with very low representation (CA and lower). If we get rid of these values now, it will help us avoid mistakes when querying later on, as if there is unrepresentative business data, it will simply be null, as opposed to giving us some aggregate numbers that we then forget are only aggregated over 10 samples, etc.
#
# All this is to say, let's just be safe and get rid of all the yelp data with state values of 23 and lower now.
#
# We should also remove any records of businesses in Canada, since the other datasets we are using all have to do with the US exclusively.
#
# Note: originally, I was going to do this part last, but after realizing that some of my decisions for preprocessing JSON would come from visualizations and null-counts, and since we decided that the aforementioned regions are not useful to us, I decided to do it first so that our preprocessing visualizations are more accurate.

# %%
#store a copy of the dataset
yelp_full = yelp.copy()

# %%
#get drop indices for states with value counts under 1000
drop_indices = yelp[yelp['state'].map(yelp['state'].value_counts() <1000)].index

yelp_reduced= yelp.drop(drop_indices, inplace=False)

#now get drop indices for Canada regions
drop_indices = yelp_reduced[yelp_reduced['state'].isin(['ON', 'QC', 'AB'])].index

yelp_reduced.drop(drop_indices, inplace=True)
yelp_reduced.reset_index(drop=True, inplace=True)

yelp_reduced['state'].value_counts()
# Out:
# AZ    60803
# NV    39084
# OH    16392
# NC    16218
# PA    12376
# WI     5525
# IL     2034
# SC     1328
# Name: state, dtype: int64

# %%
yelp_reduced.info()
yelp_reduced.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153760 entries, 0 to 153759
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   business_id   153760 non-null  object
#  1   name          153760 non-null  object
#  2   address       153760 non-null  object
#  3   city          153760 non-null  object
#  4   state         153760 non-null  object
#  5   postal_code   153760 non-null  object
#  6   latitude      153760 non-null  float64
#  7   longitude     153760 non-null  float64
#  8   stars         153760 non-null  float64
#  9   review_count  153760 non-null  int64
#  10  is_open       153760 non-null  int64
#  11  attributes    133132 non-null  object
#  12  categories    153367 non-null  object
#  13  hours         123204 non-null  object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 16.4+ MB
#               business_id                         name  \
# 0  f9NumwFMBDn751xgFiRbNA     The Range At Lake Norman
# 1  Yzvjg0SayhoZgCljUJRF9Q            Carlos Santo, NMD
# 2  6OAZjbxqM5ol29BuHsil3w         Nevada House of Hose
# 3  51M2Kk903DFYI6gnB5I6SQ      USE MY GUY SERVICES LLC
# 4  cKyLV5oWZJ2NudWgqs8VZw  Oasis Auto Center - Gilbert
#
#                      address             city state postal_code   latitude  \
# 0            10913 Bailey Rd        Cornelius    NC       28031  35.462724
# 1  8880 E Via Linda, Ste 107       Scottsdale    AZ       85258  33.569404
# 2             1015 Sharp Cir  North Las Vegas    NV       89030  36.219728
# 3         4827 E Downing Cir             Mesa    AZ       85205  33.428065
# 4  1720 W Elliot Rd, Ste 105          Gilbert    AZ       85233  33.350399
#
#     longitude  stars  review_count  is_open  \
# 0  -80.852612    3.5            36        1
# 1 -111.890264    5.0             4        1
# 2 -115.127725    2.5             3        0
# 3 -111.726648    4.5            26        1
# 4 -111.827142    4.5            38        1
#
#                                           attributes  \
# 0  {'BusinessAcceptsCreditCards': 'True', 'BikePa...
# 1  {'GoodForKids': 'True', 'ByAppointmentOnly': '...
# 2  {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 3  {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 4             {'BusinessAcceptsCreditCards': 'True'}
#
#                                           categories  \
# 0  Active Life, Gun/Rifle Ranges, Guns & Ammo, Sh...
# 1  Health & Medical, Fitness & Instruction, Yoga,...
# 2  Hardware Stores, Home Services, Building Suppl...
# 3  Home Services, Plumbing, Electricians, Handyma...
# 4  Auto Repair, Automotive, Oil Change Stations, ...
#
#                                                hours
# 0  {'Monday': '10:0-18:0', 'Tuesday': '11:0-20:0'...
# 1                                               None
# 2  {'Monday': '7:0-16:0', 'Tuesday': '7:0-16:0', ...
# 3  {'Monday': '0:0-0:0', 'Tuesday': '9:0-16:0', '...
# 4  {'Monday': '7:0-18:0', 'Tuesday': '7:0-18:0', ...

# %%
yelp_reduced['is_open'].value_counts()
# Out:
# 1    125135
# 0     28625
# Name: is_open, dtype: int64

# %%
#get rid of closed businesses, as we have no need for them
drop_indices = yelp_reduced[yelp_reduced['is_open'] == 0].index

yelp_reduced.drop(drop_indices, inplace=True)

#get rid of address and is_open, as we don't really need them
yelp_reduced.drop('address', inplace=True, axis=1)
yelp_reduced.drop('is_open', inplace=True, axis=1)

yelp_reduced.reset_index(drop=True, inplace=True)


yelp_reduced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125135 entries, 0 to 125134
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   business_id   125135 non-null  object
#  1   name          125135 non-null  object
#  2   city          125135 non-null  object
#  3   state         125135 non-null  object
#  4   postal_code   125135 non-null  object
#  5   latitude      125135 non-null  float64
#  6   longitude     125135 non-null  float64
#  7   stars         125135 non-null  float64
#  8   review_count  125135 non-null  int64
#  9   attributes    107212 non-null  object
#  10  categories    124761 non-null  object
#  11  hours         103877 non-null  object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 11.5+ MB

# %%
yelp_reduced.head()
# Out:
#               business_id                         name        city state  \
# 0  f9NumwFMBDn751xgFiRbNA     The Range At Lake Norman   Cornelius    NC
# 1  Yzvjg0SayhoZgCljUJRF9Q            Carlos Santo, NMD  Scottsdale    AZ
# 2  51M2Kk903DFYI6gnB5I6SQ      USE MY GUY SERVICES LLC        Mesa    AZ
# 3  cKyLV5oWZJ2NudWgqs8VZw  Oasis Auto Center - Gilbert     Gilbert    AZ
# 4  oiAlXZPIFm2nBCt0DHLu_Q         Green World Cleaners   Las Vegas    NV
#
#   postal_code   latitude   longitude  stars  review_count  \
# 0       28031  35.462724  -80.852612    3.5            36
# 1       85258  33.569404 -111.890264    5.0             4
# 2       85205  33.428065 -111.726648    4.5            26
# 3       85233  33.350399 -111.827142    4.5            38
# 4       89118  36.063977 -115.241463    3.5            81
#
#                                           attributes  \
# 0  {'BusinessAcceptsCreditCards': 'True', 'BikePa...
# 1  {'GoodForKids': 'True', 'ByAppointmentOnly': '...
# 2  {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 3             {'BusinessAcceptsCreditCards': 'True'}
# 4  {'BusinessParking': '{'garage': False, 'street...
#
#                                           categories  \
# 0  Active Life, Gun/Rifle Ranges, Guns & Ammo, Sh...
# 1  Health & Medical, Fitness & Instruction, Yoga,...
# 2  Home Services, Plumbing, Electricians, Handyma...
# 3  Auto Repair, Automotive, Oil Change Stations, ...
# 4  Dry Cleaning & Laundry, Local Services, Laundr...
#
#                                                hours
# 0  {'Monday': '10:0-18:0', 'Tuesday': '11:0-20:0'...
# 1                                               None
# 2  {'Monday': '0:0-0:0', 'Tuesday': '9:0-16:0', '...
# 3  {'Monday': '7:0-18:0', 'Tuesday': '7:0-18:0', ...
# 4  {'Monday': '7:0-19:0', 'Tuesday': '7:0-19:0', ...

# %%
#Now check to make sure city doesn't have any weird formatting going on. We can look for punctuation to help find out.
yelp_reduced[yelp_reduced['city'].str.contains('[^A-Za-z0-9\s]', regex = True )]
# Out:
#                    business_id                                        name  \
# 703     i9PUoStRuesSnIKWY6ZOrw            Wicked Pixie Salon & Hair Studio
# 1265    Y28XY3fko-Sdb9RBBgCDRQ                              DiBella's Subs
# 1320    squM96Zm0Ae6K3wvaHLuBw  Attention To Detail - Car Care Specialists
# 4744    dXzLioqrEncX5nONdhhjMg              Anderson's Sports Pub & Eatery
# 6124    sCLXU9ehXMNsodcZqXKNZA                           King China Buffet
# ...                        ...                                         ...
# 117308  y4giWpQy1TYYX7sZOk9NNg                                     Wendy's
# 117639  bAqt_TWv-f42GWCG2h0_8Q                           Cookies by Design
# 119535  DtrTCViUn9uV8TtD_eyMQg             Ambiance - The Store For Lovers
# 121367  TYtyWZOtKNQ1yQS1HJUApw                        Mo & Co Hair Factory
# 123900  PhOHktnhdZc6uqF90Gstmw                           Quest Diagnostics
#
#                       city state postal_code   latitude   longitude  stars  \
# 703               ​Gilbert    AZ       85297  33.276765 -111.786945    5.0
# 1265     Warrensville Hts.    OH       44122  41.447229  -81.496798    3.5
# 1320      Urbana, Illinois    IL       61802  40.115516  -88.202043    5.0
# 4744    Mentor-on-the-Lake    OH       44060  41.706009  -81.361561    3.0
# 6124    Mentor-on-the-Lake    OH       44060  41.707105  -81.361282    3.0
# ...                    ...   ...         ...        ...         ...    ...
# 117308     Middleburg Hts.    OH       44130  41.369281  -81.804608    1.0
# 117639      North Olmsted,    OH       44070  41.426557  -81.893084    5.0
# 119535       Mayfield Hts.    OH       44124  41.520459  -81.467055    3.0
# 121367   Las Vegas, Nevada    NV       89120  36.071657 -115.094138    4.5
# 123900         Mt. Lebanon    PA       15228  40.381654  -80.044566    2.0
#
#         review_count                                         attributes  \
# 703               17  {'GoodForKids': 'True', 'RestaurantsPriceRange...
# 1265              47  {'RestaurantsReservations': 'False', 'Alcohol'...
# 1320              20  {'ByAppointmentOnly': 'False', 'BusinessAccept...
# 4744              16  {'RestaurantsAttire': ''casual'', 'Restaurants...
# 6124               5  {'RestaurantsAttire': 'u'casual'', 'Restaurant...
# ...              ...                                                ...
# 117308            17  {'GoodForMeal': '{'dessert': False, 'latenight...
# 117639            10  {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 119535             4  {'BusinessParking': '{'garage': False, 'street...
# 121367             9  {'ByAppointmentOnly': 'False', 'GoodForKids': ...
# 123900             6  {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
#
#                                                categories  \
# 703     Hair Extensions, Hair Salons, Hair Removal, Bl...
# 1265                Restaurants, Delis, Salad, Sandwiches
# 1320                 Automotive, Auto Detailing, Car Wash
# 4744     Sports Bars, Irish, Nightlife, Restaurants, Bars
# 6124                                 Restaurants, Chinese
# ...                                                   ...
# 117308          Fast Food, Restaurants, Burgers, Hot Dogs
# 117639  Bakeries, Flowers & Gifts, Shopping, Food, Des...
# 119535  Adult, Personal Shopping, Lingerie, Shopping, ...
# 121367  Beauty & Spas, Barbers, Hair Salons, Hair Exte...
# 123900  Health & Medical, Laboratory Testing, Diagnost...
#
#                                                     hours
# 703     {'Monday': '10:0-18:0', 'Tuesday': '11:0-19:0'...
# 1265    {'Monday': '10:0-21:0', 'Tuesday': '10:0-21:0'...
# 1320    {'Monday': '8:0-17:0', 'Tuesday': '8:0-17:0', ...
# 4744    {'Monday': '11:0-0:0', 'Tuesday': '11:0-0:0', ...
# 6124    {'Monday': '11:0-21:30', 'Tuesday': '11:0-21:3...
# ...                                                   ...
# 117308  {'Monday': '10:0-1:0', 'Tuesday': '10:0-1:0', ...
# 117639  {'Monday': '8:0-18:0', 'Tuesday': '8:0-18:0', ...
# 119535  {'Monday': '0:0-0:0', 'Tuesday': '10:0-21:0', ...
# 121367  {'Monday': '9:0-17:0', 'Tuesday': '9:0-17:0', ...
# 123900  {'Monday': '12:0-14:30', 'Tuesday': '12:0-14:3...
#
# [92 rows x 12 columns]

# %% [markdown]
# We see that some of our city values do contain punctuation. Some of these seem fine (periods for abbreviatons, dashes for certain hyphenated names, etc.), but the commas are interesting. It seems some of our cities also have an unneccessary state attached. Let's fix that.

# %%
yelp_reduced['city'] = yelp_reduced['city'].apply(lambda x: x.split(',')[0])

yelp_reduced[yelp_reduced['city'].str.contains(',')]
# Out:
# Empty DataFrame
# Columns: [business_id, name, city, state, postal_code, latitude, longitude, stars, review_count, attributes, categories, hours]
# Index: []

# %%
#Check for nulls again
yelp_reduced.isna().sum()
# Out:
# business_id         0
# name                0
# city                0
# state               0
# postal_code         0
# latitude            0
# longitude           0
# stars               0
# review_count        0
# attributes      17923
# categories        374
# hours           21258
# dtype: int64

# %% [markdown]
# ## Zipcode entity Resolution

# %%
zips = pd.read_csv('zip_data.csv')
zips
# Out:
#          zip      type  decommissioned primary_city state  \
# 0        501    UNIQUE               0   Holtsville    NY
# 1        544    UNIQUE               0   Holtsville    NY
# 2       1001  STANDARD               0       Agawam    MA
# 3       1002  STANDARD               0      Amherst    MA
# 4       1003    PO BOX               0      Amherst    MA
# ...      ...       ...             ...          ...   ...
# 41696  99926    PO BOX               0   Metlakatla    AK
# 41697  99927    PO BOX               0  Point Baker    AK
# 41698  99928    PO BOX               0    Ward Cove    AK
# 41699  99929    PO BOX               0     Wrangell    AK
# 41700  99950    PO BOX               0    Ketchikan    AK
#
#                                   county country  latitude  longitude  \
# 0                         Suffolk County      US     40.81     -73.04
# 1                         Suffolk County      US     40.81     -73.04
# 2                         Hampden County      US     42.06     -72.61
# 3                       Hampshire County      US     42.37     -72.52
# 4                       Hampshire County      US     42.39     -72.52
# ...                                  ...     ...       ...        ...
# 41696  Prince Of Wales-Hyder Census Area      US     55.14    -131.49
# 41697  Prince Of Wales-Hyder Census Area      US     56.30    -133.57
# 41698          Ketchikan Gateway Borough      US     55.45    -131.79
# 41699          Wrangell City And Borough      US     56.41    -131.61
# 41700  Prince Of Wales-Hyder Census Area      US     55.34    -131.64
#
#        irs_estimated_population_2015
# 0                                562
# 1                                  0
# 2                              15220
# 3                              16570
# 4                                184
# ...                              ...
# 41696                           1140
# 41697                             48
# 41698                           1530
# 41699                           2145
# 41700                            262
#
# [41701 rows x 10 columns]

# %%
type(zips['zip'][0])
# Out:
# numpy.int64

# %%
type(yelp_reduced['postal_code'][0])
# Out:
# str

# %%
# We have spome blank values that are also not nulls that will make type conversion difficult.
yelp_reduced[yelp_reduced['postal_code'] == '']
# Out:
#                    business_id                                   name  \
# 751     gTn_YaXUYEC5py8ESrX5Wg                              Maki Taco
# 904     dWapY1yn-vG_ECu67AIEKg                       Bebo's Mac Shack
# 1329    EIo9thPJJ86soQdnpyK7EA                   SuperFarm SuperTruck
# 1749    RPpHS-I4Xf-IbQWb-iSDvA                Beckham's B&M Bar-B-Que
# 2502    EeOrrSmqNIoVnLW9kjEfOg        Scottsdale Neighborhood Trolley
# ...                        ...                                    ...
# 123387  ofqNprsSZVhx9Hq2wRoLWA  Patrick Burt Sculpted Jewelry Designs
# 123598  7s43BalhWiHze8ckwZpegA                              Noca Wich
# 123751  tseZGhzyTJgP_zJSqjzAFQ           Homeward Bound Cat Adoptions
# 123825  ebBjWSi7JQykAB05dykqGA                          Envoy America
# 124756  D9TAaAszdk5MN8DLJx6PlQ                          olive and Ivy
#
#               city state postal_code   latitude   longitude  stars  \
# 751      Charlotte    NC              35.227087  -80.843127    3.0
# 904      Charlotte    NC              35.227087  -80.843127    2.5
# 1329          Mesa    AZ              33.350782 -111.653307    3.5
# 1749     Cleveland    OH              41.499320  -81.694361    4.0
# 2502    Scottsdale    AZ              33.494170 -111.926052    5.0
# ...            ...   ...         ...        ...         ...    ...
# 123387       Tempe    AZ              33.380022 -111.941030    5.0
# 123598     Central    AZ              33.434162 -111.996949    2.0
# 123751   Las Vegas    NV              36.175000 -115.136389    4.0
# 123825     Phoenix    AZ              33.448377 -112.074037    5.0
# 124756     Phoenix    AZ              33.437580 -112.031227    4.0
#
#         review_count                                         attributes  \
# 751               40  {'RestaurantsPriceRange2': '1', 'RestaurantsGo...
# 904                7  {'RestaurantsPriceRange2': '1', 'Caters': 'Tru...
# 1329              30  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 1749               4  {'Caters': 'True', 'RestaurantsDelivery': 'Fal...
# 2502               5                                               None
# ...              ...                                                ...
# 123387             3  {'BusinessParking': '{'garage': False, 'street...
# 123598            39  {'GoodForMeal': '{'dessert': False, 'latenight...
# 123751            10                                               None
# 123825             4                                               None
# 124756             3  {'Ambience': '{'touristy': False, 'hipster': F...
#
#                                                categories  \
# 751     Food Stands, Street Vendors, Restaurants, Mexi...
# 904     Food, Burgers, Food Stands, Food Trucks, Resta...
# 1329                                 Food, Street Vendors
# 1749                                    Food, Food Trucks
# 2502    Transportation, Public Transportation, Hotels ...
# ...                                                   ...
# 123387  Local Flavor, Shopping, Local Services, Jewelr...
# 123598                   Restaurants, Mexican, Sandwiches
# 123751                              Pets, Animal Shelters
# 123825  Medical Transportation, Health & Medical, Loca...
# 124756                            Restaurants, Sandwiches
#
#                                                     hours
# 751     {'Monday': '11:0-14:0', 'Wednesday': '11:0-14:...
# 904     {'Monday': '9:0-9:0', 'Tuesday': '9:0-9:0', 'W...
# 1329                                                 None
# 1749                                                 None
# 2502                                                 None
# ...                                                   ...
# 123387                                               None
# 123598                                               None
# 123751  {'Thursday': '15:0-18:0', 'Friday': '15:0-18:0...
# 123825                                               None
# 124756                                               None
#
# [214 rows x 12 columns]

# %%
#Convert blank string values to nulls
yelp_reduced.replace('', np.nan, inplace=True)
yelp_reduced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125135 entries, 0 to 125134
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   business_id   125135 non-null  object
#  1   name          125134 non-null  object
#  2   city          125134 non-null  object
#  3   state         125135 non-null  object
#  4   postal_code   124921 non-null  object
#  5   latitude      125135 non-null  float64
#  6   longitude     125135 non-null  float64
#  7   stars         125135 non-null  float64
#  8   review_count  125135 non-null  int64
#  9   attributes    107212 non-null  object
#  10  categories    124761 non-null  object
#  11  hours         103877 non-null  object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 11.5+ MB

# %% [markdown]
# Seems yelp messed up and accidentally set a Toronto business to be in OH instead of ON. Let's drop that.

# %%
yelp_reduced[yelp_reduced['postal_code'].str.isnumeric() ==False]
# Out:
#                   business_id        name     city state postal_code  \
# 82403  wfe31gLa1qtAgiCVI0cH2g  Pastucci's  Toronto    OH     M8Z 1N1
#
#         latitude  longitude  stars  review_count  \
# 82403  43.625879 -79.504026    4.0            25
#
#                                               attributes  \
# 82403  {'BusinessAcceptsBitcoin': 'False', 'DogsAllow...
#
#                                               categories  \
# 82403  Restaurants, Italian, Food, Specialty Food, Sa...
#
#                                                    hours
# 82403  {'Monday': '0:0-0:0', 'Tuesday': '11:0-22:0', ...

# %%
drop_index = yelp_reduced[yelp_reduced['postal_code'].str.isnumeric() ==False].index
yelp_reduced.drop(drop_index, inplace =True)
yelp_reduced.reset_index(drop=True, inplace=True)

yelp_reduced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125134 entries, 0 to 125133
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   business_id   125134 non-null  object
#  1   name          125133 non-null  object
#  2   city          125133 non-null  object
#  3   state         125134 non-null  object
#  4   postal_code   124920 non-null  object
#  5   latitude      125134 non-null  float64
#  6   longitude     125134 non-null  float64
#  7   stars         125134 non-null  float64
#  8   review_count  125134 non-null  int64
#  9   attributes    107211 non-null  object
#  10  categories    124760 non-null  object
#  11  hours         103876 non-null  object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 11.5+ MB

# %%
yelp_reduced['postal_code'] = yelp_reduced['postal_code'].apply(lambda x: int(x) if type(x) == str  else x)

# %%
yelp_reduced.max()
# Out:
# business_id     zzwicjPC9g246MK2M1ZFBA
# state                               WI
# postal_code                     891118
# latitude                       43.7519
# longitude                      -76.804
# stars                                5
# review_count                     10129
# dtype: object

# %%
yelp_reduced.min()
# Out:
# business_id     --7zmmkVg-IMGaXbuVd0SQ
# state                               AZ
# postal_code                       2645
# latitude                       33.1035
# longitude                     -115.493
# stars                                1
# review_count                         3
# dtype: object

# %%
zips.max()
# Out:
# zip                               99950
# type                             UNIQUE
# decommissioned                        1
# primary_city                     Zwolle
# state                                WY
# country                              US
# latitude                          71.28
# longitude                         33.53
# irs_estimated_population_2015    114420
# dtype: object

# %%
zips.min()
# Out:
# zip                                     501
# type                               MILITARY
# decommissioned                            0
# primary_city                     Aaronsburg
# state                                    AE
# country                                  IQ
# latitude                             -44.25
# longitude                           -176.63
# irs_estimated_population_2015             0
# dtype: object

# %%
#Check if we have any yelp zip codes not included in our zips file

yelp_reduced[~yelp_reduced['postal_code'].isin(zips['zip'])]['postal_code'].value_counts()
# Out:
# 85384.0     2
# 891118.0    1
# 44245.0     1
# 84224.0     1
# 85474.0     1
# 82595.0     1
# 44034.0     1
# 28225.0     1
# 35715.0     1
# 282010.0    1
# 85831.0     1
# 27273.0     1
# 89417.0     1
# 28251.0     1
# 88979.0     1
# 89184.0     1
# 15109.0     1
# 85394.0     1
# 88147.0     1
# 43714.0     1
# 44219.0     1
# 86006.0     1
# 71863.0     1
# 65241.0     1
# 85896.0     1
# 85052.0     1
# 15804.0     1
# Name: postal_code, dtype: int64

# %%
yelp_reduced[~yelp_reduced['postal_code'].isin(zips['zip'])]
# Out:
#                    business_id                             name        city  \
# 751     gTn_YaXUYEC5py8ESrX5Wg                        Maki Taco   Charlotte
# 904     dWapY1yn-vG_ECu67AIEKg                 Bebo's Mac Shack   Charlotte
# 1329    EIo9thPJJ86soQdnpyK7EA             SuperFarm SuperTruck        Mesa
# 1749    RPpHS-I4Xf-IbQWb-iSDvA          Beckham's B&M Bar-B-Que   Cleveland
# 2502    EeOrrSmqNIoVnLW9kjEfOg  Scottsdale Neighborhood Trolley  Scottsdale
# ...                        ...                              ...         ...
# 123597  7s43BalhWiHze8ckwZpegA                        Noca Wich     Central
# 123750  tseZGhzyTJgP_zJSqjzAFQ     Homeward Bound Cat Adoptions   Las Vegas
# 123824  ebBjWSi7JQykAB05dykqGA                    Envoy America     Phoenix
# 123848  m1FVKF2easFE23iziLPThA      Pulp Juice And Smoothie Bar       Solon
# 124755  D9TAaAszdk5MN8DLJx6PlQ                    olive and Ivy     Phoenix
#
#        state  postal_code   latitude   longitude  stars  review_count  \
# 751       NC          NaN  35.227087  -80.843127    3.0            40
# 904       NC          NaN  35.227087  -80.843127    2.5             7
# 1329      AZ          NaN  33.350782 -111.653307    3.5            30
# 1749      OH          NaN  41.499320  -81.694361    4.0             4
# 2502      AZ          NaN  33.494170 -111.926052    5.0             5
# ...      ...          ...        ...         ...    ...           ...
# 123597    AZ          NaN  33.434162 -111.996949    2.0            39
# 123750    NV          NaN  36.175000 -115.136389    4.0            10
# 123824    AZ          NaN  33.448377 -112.074037    5.0             4
# 123848    OH      44219.0  41.383761  -81.435060    3.5             9
# 124755    AZ          NaN  33.437580 -112.031227    4.0             3
#
#                                                attributes  \
# 751     {'RestaurantsPriceRange2': '1', 'RestaurantsGo...
# 904     {'RestaurantsPriceRange2': '1', 'Caters': 'Tru...
# 1329    {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 1749    {'Caters': 'True', 'RestaurantsDelivery': 'Fal...
# 2502                                                 None
# ...                                                   ...
# 123597  {'GoodForMeal': '{'dessert': False, 'latenight...
# 123750                                               None
# 123824                                               None
# 123848  {'GoodForMeal': '{'dessert': False, 'latenight...
# 124755  {'Ambience': '{'touristy': False, 'hipster': F...
#
#                                                categories  \
# 751     Food Stands, Street Vendors, Restaurants, Mexi...
# 904     Food, Burgers, Food Stands, Food Trucks, Resta...
# 1329                                 Food, Street Vendors
# 1749                                    Food, Food Trucks
# 2502    Transportation, Public Transportation, Hotels ...
# ...                                                   ...
# 123597                   Restaurants, Mexican, Sandwiches
# 123750                              Pets, Animal Shelters
# 123824  Medical Transportation, Health & Medical, Loca...
# 123848  Food, Juice Bars & Smoothies, Salad, Sandwiche...
# 124755                            Restaurants, Sandwiches
#
#                                                     hours
# 751     {'Monday': '11:0-14:0', 'Wednesday': '11:0-14:...
# 904     {'Monday': '9:0-9:0', 'Tuesday': '9:0-9:0', 'W...
# 1329                                                 None
# 1749                                                 None
# 2502                                                 None
# ...                                                   ...
# 123597                                               None
# 123750  {'Thursday': '15:0-18:0', 'Friday': '15:0-18:0...
# 123824                                               None
# 123848  {'Monday': '7:0-21:0', 'Tuesday': '7:0-21:0', ...
# 124755                                               None
#
# [242 rows x 12 columns]

# %% [markdown]
# There aren't many businesses not represented in our zipcode table, which is good! Let's get rid of the few that aren't so that we don't have any referential integrity issues making postal_code a foreign key to zip

# %%
drop_indices = yelp_reduced[~yelp_reduced['postal_code'].isin(zips['zip'])].index

yelp_reduced.drop(drop_indices, inplace=True)

yelp_reduced.reset_index(drop=True, inplace=True)


yelp_reduced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124892 entries, 0 to 124891
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   business_id   124892 non-null  object
#  1   name          124891 non-null  object
#  2   city          124892 non-null  object
#  3   state         124892 non-null  object
#  4   postal_code   124892 non-null  float64
#  5   latitude      124892 non-null  float64
#  6   longitude     124892 non-null  float64
#  7   stars         124892 non-null  float64
#  8   review_count  124892 non-null  int64
#  9   attributes    107064 non-null  object
#  10  categories    124518 non-null  object
#  11  hours         103794 non-null  object
# dtypes: float64(4), int64(1), object(7)
# memory usage: 11.4+ MB

# %%
yelp_reduced[~yelp_reduced['postal_code'].isin(zips['zip'])]
# Out:
# Empty DataFrame
# Columns: [business_id, name, city, state, postal_code, latitude, longitude, stars, review_count, attributes, categories, hours]
# Index: []

# %% [markdown]
# This last part is out of order, since the way I dsicovered it was a bit down the line, but we have to clean it here before we split tables.

# %%
yelp_flat[yelp_flat['name'].isna()]
# Out:
#        index             business_id name          city state  postal_code  \
# 29837  29837  LiQckUkfrmaU09DijHLLpQ  NaN  Huntersville    NC      28078.0
#
#         latitude  longitude  stars  review_count  ... attributes.GoodForKids  \
# 29837  35.383981 -80.786123    2.0             3  ...                   True
#
#       attributes.BikeParking attributes.BusinessAcceptsCreditCards  \
# 29837                    NaN                                  True
#
#       hours.Sunday hours.Saturday hours.Friday hours.Thursday hours.Wednesday  \
# 29837          NaN     9:30-12:30   10:0-20:30     10:0-20:30      10:0-20:30
#
#       hours.Tuesday hours.Monday
# 29837    10:0-20:30   10:0-20:30
#
# [1 rows x 56 columns]

# %%
#What was that NaN originally
yelp[yelp['business_id'] == 'LiQckUkfrmaU09DijHLLpQ']
# Out:
#                   business_id name             address          city state  \
# 49808  LiQckUkfrmaU09DijHLLpQ       13024 Eastfield Rd  Huntersville    NC
#
#       postal_code   latitude  longitude  stars  review_count  is_open  \
# 49808       28078  35.383981 -80.786123    2.0             3        1
#
#                                               attributes  \
# 49808  {'GoodForKids': 'True', 'BusinessAcceptsCredit...
#
#                                               categories  \
# 49808  Martial Arts, Fitness & Instruction, Active Li...
#
#                                                    hours
# 49808  {'Monday': '10:0-20:30', 'Tuesday': '10:0-20:3...

# %% [markdown]
# Interestingly enough, flattening the table also seemed to convert a blank name to NaN for us. Technically, not having a listed name doesn't mean the other data is necessarily wrong, but it is certainly suspect. Ultimately, it's only one value, and having a null value in the column might make various type-based operations on the whole column more awkward, so let's remove it to be safe.

# %%
drop_index = yelp_reduced[yelp_reduced['name'].isna()].index

yelp_reduced.drop(drop_index, inplace = True)
yelp_reduced.reset_index(drop=True, inplace=True)
yelp_reduced.head()
# Out:
#    index             business_id                         name        city  \
# 0      0  f9NumwFMBDn751xgFiRbNA     The Range At Lake Norman   Cornelius
# 1      1  Yzvjg0SayhoZgCljUJRF9Q            Carlos Santo, NMD  Scottsdale
# 2      2  51M2Kk903DFYI6gnB5I6SQ      USE MY GUY SERVICES LLC        Mesa
# 3      3  cKyLV5oWZJ2NudWgqs8VZw  Oasis Auto Center - Gilbert     Gilbert
# 4      4  oiAlXZPIFm2nBCt0DHLu_Q         Green World Cleaners   Las Vegas
#
#   state  postal_code   latitude   longitude  stars  review_count  ...  \
# 0    NC      28031.0  35.462724  -80.852612    3.5            36  ...
# 1    AZ      85258.0  33.569404 -111.890264    5.0             4  ...
# 2    AZ      85205.0  33.428065 -111.726648    4.5            26  ...
# 3    AZ      85233.0  33.350399 -111.827142    4.5            38  ...
# 4    NV      89118.0  36.063977 -115.241463    3.5            81  ...
#
#   attributes.GoodForKids attributes.BikeParking  \
# 0                  False                   True
# 1                   True                    NaN
# 2                    NaN                    NaN
# 3                    NaN                    NaN
# 4                    NaN                   True
#
#   attributes.BusinessAcceptsCreditCards hours.Sunday hours.Saturday  \
# 0                                  True    13:0-18:0      11:0-20:0
# 1                                   NaN          NaN            NaN
# 2                                  True          NaN            NaN
# 3                                  True          NaN       7:0-15:0
# 4                                  True          NaN       9:0-17:0
#
#   hours.Friday hours.Thursday hours.Wednesday hours.Tuesday hours.Monday
# 0    11:0-20:0      11:0-20:0       10:0-18:0     11:0-20:0    10:0-18:0
# 1          NaN            NaN             NaN           NaN          NaN
# 2     9:0-16:0       9:0-16:0        9:0-16:0      9:0-16:0      0:0-0:0
# 3     7:0-18:0       7:0-18:0        7:0-18:0      7:0-18:0     7:0-18:0
# 4     7:0-19:0       7:0-19:0        7:0-19:0      7:0-19:0     7:0-19:0
#
# [5 rows x 56 columns]

# %%
yelp_reduced.drop('index', axis=1, inplace=True)

# %%
yelp_reduced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124891 entries, 0 to 124890
# Data columns (total 55 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   business_id                            124891 non-null  object
#  1   name                                   124891 non-null  object
#  2   city                                   124891 non-null  object
#  3   state                                  124891 non-null  object
#  4   postal_code                            124891 non-null  float64
#  5   latitude                               124891 non-null  float64
#  6   longitude                              124891 non-null  float64
#  7   stars                                  124891 non-null  float64
#  8   review_count                           124891 non-null  int64
#  9   attributes.Open24Hours                 11 non-null      object
#  10  attributes.DietaryRestrictions         22 non-null      object
#  11  attributes.RestaurantsCounterService   10 non-null      object
#  12  attributes.AgesAllowed                 76 non-null      object
#  13  attributes.BYOBCorkage                 851 non-null     object
#  14  attributes.HairSpecializesIn           957 non-null     object
#  15  attributes.DriveThru                   2983 non-null    object
#  16  attributes.Smoking                     2567 non-null    object
#  17  attributes.Music                       4859 non-null    object
#  18  attributes.BestNights                  3673 non-null    object
#  19  attributes.CoatCheck                   3142 non-null    object
#  20  attributes.HappyHour                   9625 non-null    object
#  21  attributes.GoodForDancing              3088 non-null    object
#  22  attributes.RestaurantsTableService     10595 non-null   object
#  23  attributes.Corkage                     717 non-null     object
#  24  attributes.GoodForMeal                 18826 non-null   object
#  25  attributes.BYOB                        540 non-null     object
#  26  attributes.BusinessAcceptsBitcoin      14459 non-null   object
#  27  attributes.Ambience                    23916 non-null   object
#  28  attributes.DogsAllowed                 12164 non-null   object
#  29  attributes.AcceptsInsurance            7377 non-null    object
#  30  attributes.WheelchairAccessible        19057 non-null   object
#  31  attributes.Caters                      22663 non-null   object
#  32  attributes.OutdoorSeating              24927 non-null   object
#  33  attributes.RestaurantsDelivery         25282 non-null   object
#  34  attributes.Alcohol                     22203 non-null   object
#  35  attributes.HasTV                       23961 non-null   object
#  36  attributes.RestaurantsGoodForGroups    23369 non-null   object
#  37  attributes.RestaurantsReservations     23895 non-null   object
#  38  attributes.NoiseLevel                  20702 non-null   object
#  39  attributes.RestaurantsTakeOut          29913 non-null   object
#  40  attributes.RestaurantsAttire           20391 non-null   object
#  41  attributes.WiFi                        35705 non-null   object
#  42  attributes.RestaurantsPriceRange2      54962 non-null   object
#  43  attributes.ByAppointmentOnly           46504 non-null   object
#  44  attributes.BusinessParking             59863 non-null   object
#  45  attributes.GoodForKids                 32029 non-null   object
#  46  attributes.BikeParking                 51189 non-null   object
#  47  attributes.BusinessAcceptsCreditCards  97079 non-null   object
#  48  hours.Sunday                           58934 non-null   object
#  49  hours.Saturday                         83664 non-null   object
#  50  hours.Friday                           101545 non-null  object
#  51  hours.Thursday                         102390 non-null  object
#  52  hours.Wednesday                        102093 non-null  object
#  53  hours.Tuesday                          101377 non-null  object
#  54  hours.Monday                           98086 non-null   object
# dtypes: float64(4), int64(1), object(50)
# memory usage: 52.4+ MB

# %% [markdown]
# # Dealing With JSON

# %% [markdown]
# The main preprocessing step for our yelp data is converting our three json columns into a relational database. We have two main options here:
#
# Option 1: Keep the json columns as is and store them in a NoSql manner (indeed, MySQL does support JSON fields, so we wouldn't necessarily have to even a use a "true" NoSQL database system). However, since we cannot index a JSON field, this may become quite difficult to optimize, and considering we will likely use these columns quite a bit, that might not be the best plan.
#
# Option 2: Make our JSON into a more relational scheme by either expanding them into columns or exploding the values into new rows and breaking the corresponding column into a separate table with a many-to-one relationship with each business. This is a good deal more work, and means more joining in our queries, but I believe it will be more optimal and so is worth it.
#
# We'll go with option 2!
#
# Our JSON fields all contain different type of data:
#
# The attributes field mainly contains dictionaries with True/False values (though it does contain some nested dictionaries). This is likely best dealt with by simply expanding these values into columns of the table, since we'll likely be searching on those particular values, and compiling a list of them as we would tags does not really make sense. The main consideration here is making sure all the key value pairings at all levels of the JSON hierarchy fall under the same true/false schema, and deciding how to deal if not. Otherwise, it's just a matter of making sure we fully expand each dictionary until our schema is in 1NF (whether we do this manually or recursively).
#
# Hours contains a dictionary of days and time ranges (represented as strings). This also likely maps best to just expanding the columns, though we may have to get a bit fancy with our queries. The main considerations here are if we should convert the time strings to date-times, and also if we should store the start and end values for each time separately (or separately as well as in the original ranges), which would add a lot of extra overhead and/or space needed if we only really need time ranges, but could allow us to avoid costly regex operations in our queries if we want to frequently reference when things close and/or open irrespective to the other.
#
# The categories column contains tags that apply to the business. While technically we could one-hot encode these tags in a similar manner to the attributes, that makes querying the list of tags that belong to a business quite awkward, and also wastes a lot of space with "False" values. Instead, we will explode the tags into multiple rows and break the column into its own table with a many-to-one relationship with businesses (for normal form purposes). But first, we need to "tokenize" our category values, which are currently lists written out as strings instead of actual lists. The other thing we need to consider is if there are potentially slightly different spellings for the same tag, in which case we will likely need to do some sort of jaccard join.

# %%
#Break categories off into its own table

categories = yelp_reduced[['business_id', 'categories']]
yelp_reduced = yelp_reduced.drop(['categories'], axis = 1)

# No need to keep null values for categories as simply not being in the list tells us if a tag is not included
categories.dropna(inplace=True)

# %% [markdown]
# First, let's take care of Attributes and Hours.

# %%
yelp_flat = ft.normalize(yelp_reduced)
yelp_flat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 124892 entries, 0 to 124891
# Data columns (total 56 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   index                                  124892 non-null  int64
#  1   business_id                            124892 non-null  object
#  2   name                                   124891 non-null  object
#  3   city                                   124892 non-null  object
#  4   state                                  124892 non-null  object
#  5   postal_code                            124892 non-null  float64
#  6   latitude                               124892 non-null  float64
#  7   longitude                              124892 non-null  float64
#  8   stars                                  124892 non-null  float64
#  9   review_count                           124892 non-null  int64
#  10  attributes.Open24Hours                 11 non-null      object
#  11  attributes.DietaryRestrictions         22 non-null      object
#  12  attributes.RestaurantsCounterService   10 non-null      object
#  13  attributes.AgesAllowed                 76 non-null      object
#  14  attributes.BYOBCorkage                 851 non-null     object
#  15  attributes.HairSpecializesIn           957 non-null     object
#  16  attributes.DriveThru                   2983 non-null    object
#  17  attributes.Smoking                     2567 non-null    object
#  18  attributes.Music                       4859 non-null    object
#  19  attributes.BestNights                  3673 non-null    object
#  20  attributes.CoatCheck                   3142 non-null    object
#  21  attributes.HappyHour                   9625 non-null    object
#  22  attributes.GoodForDancing              3088 non-null    object
#  23  attributes.RestaurantsTableService     10595 non-null   object
#  24  attributes.Corkage                     717 non-null     object
#  25  attributes.GoodForMeal                 18826 non-null   object
#  26  attributes.BYOB                        540 non-null     object
#  27  attributes.BusinessAcceptsBitcoin      14459 non-null   object
#  28  attributes.Ambience                    23916 non-null   object
#  29  attributes.DogsAllowed                 12164 non-null   object
#  30  attributes.AcceptsInsurance            7377 non-null    object
#  31  attributes.WheelchairAccessible        19057 non-null   object
#  32  attributes.Caters                      22663 non-null   object
#  33  attributes.OutdoorSeating              24927 non-null   object
#  34  attributes.RestaurantsDelivery         25282 non-null   object
#  35  attributes.Alcohol                     22203 non-null   object
#  36  attributes.HasTV                       23961 non-null   object
#  37  attributes.RestaurantsGoodForGroups    23369 non-null   object
#  38  attributes.RestaurantsReservations     23895 non-null   object
#  39  attributes.NoiseLevel                  20702 non-null   object
#  40  attributes.RestaurantsTakeOut          29913 non-null   object
#  41  attributes.RestaurantsAttire           20391 non-null   object
#  42  attributes.WiFi                        35705 non-null   object
#  43  attributes.RestaurantsPriceRange2      54962 non-null   object
#  44  attributes.ByAppointmentOnly           46504 non-null   object
#  45  attributes.BusinessParking             59863 non-null   object
#  46  attributes.GoodForKids                 32030 non-null   object
#  47  attributes.BikeParking                 51189 non-null   object
#  48  attributes.BusinessAcceptsCreditCards  97080 non-null   object
#  49  hours.Sunday                           58934 non-null   object
#  50  hours.Saturday                         83665 non-null   object
#  51  hours.Friday                           101546 non-null  object
#  52  hours.Thursday                         102391 non-null  object
#  53  hours.Wednesday                        102094 non-null  object
#  54  hours.Tuesday                          101378 non-null  object
#  55  hours.Monday                           98087 non-null   object
# dtypes: float64(4), int64(2), object(50)
# memory usage: 54.3+ MB

# %% [markdown]
# ## Hours

# %% [markdown]
# For hours, if we simply normalize without doing anything with the null values, we get an ambiguous situation where NaN represents both businesses that are not open on that day as well as businesses that contained no hour information at all. This is not good- we want to replace the NaNs in the former situation with something like a 'Closed' string instead. We could do this by looking at each column and changing the NaN value if any of the other hour columns are not null.

# %%
def null_to_closed(series, thresh, replacement_string):
    # if at least one of the hours columns has a non null value, fill all the hour nulls with "Closed"
    if series.isna().sum() < thresh:
        series.fillna(replacement_string, inplace = True)
    
    return series

# %%
hours = yelp_flat[['hours.Sunday','hours.Saturday', 'hours.Monday', 'hours.Tuesday', 'hours.Wednesday', 'hours.Thursday', 'hours.Friday']]
#7 hours columns, so set thresh at 7
hours = hours.apply(null_to_closed, args=(7, "Closed"), axis =1)

# %% [markdown]
# It will likely be more useful to us to have open and close times indiviudally rather than as range-denoting strings, so let's expand each hour column into two. I'm not converting into datetimes here as we also have strings- it may be better to convert within the SQL query

# %%
hours['hours.Sunday_open'] = hours['hours.Sunday'].apply(lambda x: x.split('-')[0] if (type(x) == str and x != 'Closed') else x)
hours['hours.Sunday_closed'] = hours['hours.Sunday'].apply(lambda x: x.split('-')[1] if (type(x) == str and x != 'Closed') else x)
hours['hours.Saturday_open'] = hours['hours.Saturday'].apply(lambda x: x.split('-')[0] if (type(x) == str and x != 'Closed') else x)
hours['hours.Saturday_closed'] = hours['hours.Saturday'].apply(lambda x: x.split('-')[1] if (type(x) == str and x != 'Closed') else x)
hours['hours.Monday_open'] = hours['hours.Monday'].apply(lambda x: x.split('-')[0] if (type(x) == str and x != 'Closed') else x)
hours['hours.Monday_closed'] = hours['hours.Monday'].apply(lambda x: x.split('-')[1] if (type(x) == str and x != 'Closed') else x)
hours['hours.Tuesday_open'] = hours['hours.Tuesday'].apply(lambda x: x.split('-')[0] if (type(x) == str and x != 'Closed') else x)
hours['hours.Tuesday_closed'] = hours['hours.Tuesday'].apply(lambda x: x.split('-')[1] if (type(x) == str and x != 'Closed') else x)
hours['hours.Wednesday_open'] = hours['hours.Wednesday'].apply(lambda x: x.split('-')[0] if (type(x) == str and x != 'Closed') else x)
hours['hours.Wednesday_closed'] = hours['hours.Wednesday'].apply(lambda x: x.split('-')[1] if (type(x) == str and x != 'Closed') else x)
hours['hours.Thursday_open'] = hours['hours.Thursday'].apply(lambda x: x.split('-')[0] if (type(x) == str and x != 'Closed') else x)
hours['hours.Thursday_closed'] = hours['hours.Thursday'].apply(lambda x: x.split('-')[1] if (type(x) == str and x != 'Closed') else x)
hours['hours.Friday_open'] = hours['hours.Friday'].apply(lambda x: x.split('-')[0] if (type(x) == str and x != 'Closed') else x)
hours['hours.Friday_closed'] = hours['hours.Friday'].apply(lambda x: x.split('-')[1] if (type(x) == str and x != 'Closed') else x)
hours.head()
# Out:
#   hours.Sunday hours.Saturday hours.Monday hours.Tuesday hours.Wednesday  \
# 0    13:0-18:0      11:0-20:0    10:0-18:0     11:0-20:0       10:0-18:0
# 1          NaN            NaN          NaN           NaN             NaN
# 2       Closed         Closed      0:0-0:0      9:0-16:0        9:0-16:0
# 3       Closed       7:0-15:0     7:0-18:0      7:0-18:0        7:0-18:0
# 4       Closed       9:0-17:0     7:0-19:0      7:0-19:0        7:0-19:0
#
#   hours.Thursday hours.Friday hours.Sunday_open hours.Sunday_closed  \
# 0      11:0-20:0    11:0-20:0              13:0                18:0
# 1            NaN          NaN               NaN                 NaN
# 2       9:0-16:0     9:0-16:0            Closed              Closed
# 3       7:0-18:0     7:0-18:0            Closed              Closed
# 4       7:0-19:0     7:0-19:0            Closed              Closed
#
#   hours.Saturday_open  ... hours.Monday_open hours.Monday_closed  \
# 0                11:0  ...              10:0                18:0
# 1                 NaN  ...               NaN                 NaN
# 2              Closed  ...               0:0                 0:0
# 3                 7:0  ...               7:0                18:0
# 4                 9:0  ...               7:0                19:0
#
#   hours.Tuesday_open hours.Tuesday_closed hours.Wednesday_open  \
# 0               11:0                 20:0                 10:0
# 1                NaN                  NaN                  NaN
# 2                9:0                 16:0                  9:0
# 3                7:0                 18:0                  7:0
# 4                7:0                 19:0                  7:0
#
#   hours.Wednesday_closed hours.Thursday_open hours.Thursday_closed  \
# 0                   18:0                11:0                  20:0
# 1                    NaN                 NaN                   NaN
# 2                   16:0                 9:0                  16:0
# 3                   18:0                 7:0                  18:0
# 4                   19:0                 7:0                  19:0
#
#   hours.Friday_open hours.Friday_closed
# 0              11:0                20:0
# 1               NaN                 NaN
# 2               9:0                16:0
# 3               7:0                18:0
# 4               7:0                19:0
#
# [5 rows x 21 columns]

# %%
yelp_flat.drop(['hours.Sunday','hours.Saturday', 'hours.Friday', 'hours.Thursday', 'hours.Wednesday', 'hours.Tuesday', 'hours.Monday'], axis=1, inplace=True)
yelp_flat = pd.concat([yelp_flat, hours], join='inner', axis=1)
yelp_flat.drop(['hours.Sunday','hours.Saturday', 'hours.Friday', 'hours.Thursday', 'hours.Wednesday', 'hours.Tuesday', 'hours.Monday'], axis=1, inplace=True)

yelp_flat.head()
# Out:
#               business_id                         name        city state  \
# 0  f9NumwFMBDn751xgFiRbNA     The Range At Lake Norman   Cornelius    NC
# 1  Yzvjg0SayhoZgCljUJRF9Q            Carlos Santo, NMD  Scottsdale    AZ
# 2  51M2Kk903DFYI6gnB5I6SQ      USE MY GUY SERVICES LLC        Mesa    AZ
# 3  cKyLV5oWZJ2NudWgqs8VZw  Oasis Auto Center - Gilbert     Gilbert    AZ
# 4  oiAlXZPIFm2nBCt0DHLu_Q         Green World Cleaners   Las Vegas    NV
#
#    postal_code   latitude   longitude  stars  review_count  \
# 0      28031.0  35.462724  -80.852612    3.5            36
# 1      85258.0  33.569404 -111.890264    5.0             4
# 2      85205.0  33.428065 -111.726648    4.5            26
# 3      85233.0  33.350399 -111.827142    4.5            38
# 4      89118.0  36.063977 -115.241463    3.5            81
#
#   attributes.Open24Hours  ... hours.Monday_open hours.Monday_closed  \
# 0                    NaN  ...              10:0                18:0
# 1                    NaN  ...               NaN                 NaN
# 2                    NaN  ...               0:0                 0:0
# 3                    NaN  ...               7:0                18:0
# 4                    NaN  ...               7:0                19:0
#
#   hours.Tuesday_open hours.Tuesday_closed hours.Wednesday_open  \
# 0               11:0                 20:0                 10:0
# 1                NaN                  NaN                  NaN
# 2                9:0                 16:0                  9:0
# 3                7:0                 18:0                  7:0
# 4                7:0                 19:0                  7:0
#
#   hours.Wednesday_closed hours.Thursday_open hours.Thursday_closed  \
# 0                   18:0                11:0                  20:0
# 1                    NaN                 NaN                   NaN
# 2                   16:0                 9:0                  16:0
# 3                   18:0                 7:0                  18:0
# 4                   19:0                 7:0                  19:0
#
#   hours.Friday_open hours.Friday_closed
# 0              11:0                20:0
# 1               NaN                 NaN
# 2               9:0                16:0
# 3               7:0                18:0
# 4               7:0                19:0
#
# [5 rows x 62 columns]

# %% [markdown]
# ## Attributes

# %% [markdown]
# We have a ton of attribute columns, and likely don't need them all. Let's choose which ones to keep based off what might actually be useful so we can lower our dataset size.
#
# Note: In the final table, I'll also include the JSON attributes dictionary so if we want to try doing things the NoSQL way we can (and if that works maybe we can delete the relational attribute columns from the db).

# %%
#First, get a list of just the columns with the 'attributes.' prefix. We can then use the indices of these rows to delete them all
#from the yelp table, and add back in only the attributes we want
attributes = yelp_flat.filter(regex='^attributes.',axis=1)

#Renaming the price range attribute to get rid of the weird 2
attributes['attributes.RestaurantsPriceRange'] = attributes['attributes.RestaurantsPriceRange2']
# Out:
# C:\Users\galla\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# We still have a similar problem as we had with Hours, where we need to differentiate between an attribute not being in a dictionary vs the dictionary itself being nonexistent for the business.

# %%
attributes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124891 entries, 0 to 124890
# Data columns (total 40 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   attributes.Open24Hours                 11 non-null     object
#  1   attributes.DietaryRestrictions         22 non-null     object
#  2   attributes.RestaurantsCounterService   10 non-null     object
#  3   attributes.AgesAllowed                 76 non-null     object
#  4   attributes.BYOBCorkage                 851 non-null    object
#  5   attributes.HairSpecializesIn           957 non-null    object
#  6   attributes.DriveThru                   2983 non-null   object
#  7   attributes.Smoking                     2567 non-null   object
#  8   attributes.Music                       4859 non-null   object
#  9   attributes.BestNights                  3673 non-null   object
#  10  attributes.CoatCheck                   3142 non-null   object
#  11  attributes.HappyHour                   9625 non-null   object
#  12  attributes.GoodForDancing              3088 non-null   object
#  13  attributes.RestaurantsTableService     10595 non-null  object
#  14  attributes.Corkage                     717 non-null    object
#  15  attributes.GoodForMeal                 18826 non-null  object
#  16  attributes.BYOB                        540 non-null    object
#  17  attributes.BusinessAcceptsBitcoin      14459 non-null  object
#  18  attributes.Ambience                    23916 non-null  object
#  19  attributes.DogsAllowed                 12164 non-null  object
#  20  attributes.AcceptsInsurance            7377 non-null   object
#  21  attributes.WheelchairAccessible        19057 non-null  object
#  22  attributes.Caters                      22663 non-null  object
#  23  attributes.OutdoorSeating              24927 non-null  object
#  24  attributes.RestaurantsDelivery         25282 non-null  object
#  25  attributes.Alcohol                     22203 non-null  object
#  26  attributes.HasTV                       23961 non-null  object
#  27  attributes.RestaurantsGoodForGroups    23369 non-null  object
#  28  attributes.RestaurantsReservations     23895 non-null  object
#  29  attributes.NoiseLevel                  20702 non-null  object
#  30  attributes.RestaurantsTakeOut          29913 non-null  object
#  31  attributes.RestaurantsAttire           20391 non-null  object
#  32  attributes.WiFi                        35705 non-null  object
#  33  attributes.RestaurantsPriceRange2      54962 non-null  object
#  34  attributes.ByAppointmentOnly           46504 non-null  object
#  35  attributes.BusinessParking             59863 non-null  object
#  36  attributes.GoodForKids                 32029 non-null  object
#  37  attributes.BikeParking                 51189 non-null  object
#  38  attributes.BusinessAcceptsCreditCards  97079 non-null  object
#  39  attributes.RestaurantsPriceRange       54962 non-null  object
# dtypes: object(40)
# memory usage: 38.1+ MB

# %%
'''
Reminder of what our null_to_closed function looks like

def null_to_closed(series, thresh, replacement_string):
    # if at least one of the hours columns has a non null value, fill all the hour nulls with "Closed"
    if series.isna().sum() < thresh:
        series.fillna(replacement_string, inplace= True)
    
    return series
'''

attributes = attributes.apply(null_to_closed, args = (40, "Unlisted"), axis =1)
attributes.info()
attributes.head(40)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124891 entries, 0 to 124890
# Data columns (total 40 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   attributes.Open24Hours                 107063 non-null  object
#  1   attributes.DietaryRestrictions         107063 non-null  object
#  2   attributes.RestaurantsCounterService   107063 non-null  object
#  3   attributes.AgesAllowed                 107063 non-null  object
#  4   attributes.BYOBCorkage                 107063 non-null  object
#  5   attributes.HairSpecializesIn           107063 non-null  object
#  6   attributes.DriveThru                   107063 non-null  object
#  7   attributes.Smoking                     107063 non-null  object
#  8   attributes.Music                       107063 non-null  object
#  9   attributes.BestNights                  107063 non-null  object
#  10  attributes.CoatCheck                   107063 non-null  object
#  11  attributes.HappyHour                   107063 non-null  object
#  12  attributes.GoodForDancing              107063 non-null  object
#  13  attributes.RestaurantsTableService     107063 non-null  object
#  14  attributes.Corkage                     107063 non-null  object
#  15  attributes.GoodForMeal                 107063 non-null  object
#  16  attributes.BYOB                        107063 non-null  object
#  17  attributes.BusinessAcceptsBitcoin      107063 non-null  object
#  18  attributes.Ambience                    107063 non-null  object
#  19  attributes.DogsAllowed                 107063 non-null  object
#  20  attributes.AcceptsInsurance            107063 non-null  object
#  21  attributes.WheelchairAccessible        107063 non-null  object
#  22  attributes.Caters                      107063 non-null  object
#  23  attributes.OutdoorSeating              107063 non-null  object
#  24  attributes.RestaurantsDelivery         107063 non-null  object
#  25  attributes.Alcohol                     107063 non-null  object
#  26  attributes.HasTV                       107063 non-null  object
#  27  attributes.RestaurantsGoodForGroups    107063 non-null  object
#  28  attributes.RestaurantsReservations     107063 non-null  object
#  29  attributes.NoiseLevel                  107063 non-null  object
#  30  attributes.RestaurantsTakeOut          107063 non-null  object
#  31  attributes.RestaurantsAttire           107063 non-null  object
#  32  attributes.WiFi                        107063 non-null  object
#  33  attributes.RestaurantsPriceRange2      107063 non-null  object
#  34  attributes.ByAppointmentOnly           107063 non-null  object
#  35  attributes.BusinessParking             107063 non-null  object
#  36  attributes.GoodForKids                 107063 non-null  object
#  37  attributes.BikeParking                 107063 non-null  object
#  38  attributes.BusinessAcceptsCreditCards  107063 non-null  object
#  39  attributes.RestaurantsPriceRange       107063 non-null  object
# dtypes: object(40)
# memory usage: 38.1+ MB
#    attributes.Open24Hours attributes.DietaryRestrictions  \
# 0                Unlisted                       Unlisted
# 1                Unlisted                       Unlisted
# 2                Unlisted                       Unlisted
# 3                Unlisted                       Unlisted
# 4                Unlisted                       Unlisted
# 5                Unlisted                       Unlisted
# 6                Unlisted                       Unlisted
# 7                Unlisted                       Unlisted
# 8                Unlisted                       Unlisted
# 9                Unlisted                       Unlisted
# 10               Unlisted                       Unlisted
# 11               Unlisted                       Unlisted
# 12               Unlisted                       Unlisted
# 13               Unlisted                       Unlisted
# 14               Unlisted                       Unlisted
# 15               Unlisted                       Unlisted
# 16               Unlisted                       Unlisted
# 17               Unlisted                       Unlisted
# 18               Unlisted                       Unlisted
# 19               Unlisted                       Unlisted
# 20               Unlisted                       Unlisted
# 21               Unlisted                       Unlisted
# 22               Unlisted                       Unlisted
# 23               Unlisted                       Unlisted
# 24               Unlisted                       Unlisted
# 25               Unlisted                       Unlisted
# 26               Unlisted                       Unlisted
# 27               Unlisted                       Unlisted
# 28               Unlisted                       Unlisted
# 29               Unlisted                       Unlisted
# 30               Unlisted                       Unlisted
# 31               Unlisted                       Unlisted
# 32               Unlisted                       Unlisted
# 33               Unlisted                       Unlisted
# 34                    NaN                            NaN
# 35               Unlisted                       Unlisted
# 36               Unlisted                       Unlisted
# 37               Unlisted                       Unlisted
# 38               Unlisted                       Unlisted
# 39                    NaN                            NaN
#
#    attributes.RestaurantsCounterService attributes.AgesAllowed  \
# 0                              Unlisted               Unlisted
# 1                              Unlisted               Unlisted
# 2                              Unlisted               Unlisted
# 3                              Unlisted               Unlisted
# 4                              Unlisted               Unlisted
# 5                              Unlisted               Unlisted
# 6                              Unlisted               Unlisted
# 7                              Unlisted               Unlisted
# 8                              Unlisted               Unlisted
# 9                              Unlisted               Unlisted
# 10                             Unlisted               Unlisted
# 11                             Unlisted               Unlisted
# 12                             Unlisted               Unlisted
# 13                             Unlisted               Unlisted
# 14                             Unlisted               Unlisted
# 15                             Unlisted               Unlisted
# 16                             Unlisted               Unlisted
# 17                             Unlisted               Unlisted
# 18                             Unlisted               Unlisted
# 19                             Unlisted               Unlisted
# 20                             Unlisted               Unlisted
# 21                             Unlisted               Unlisted
# 22                             Unlisted               Unlisted
# 23                             Unlisted               Unlisted
# 24                             Unlisted               Unlisted
# 25                             Unlisted               Unlisted
# 26                             Unlisted               Unlisted
# 27                             Unlisted               Unlisted
# 28                             Unlisted               Unlisted
# 29                             Unlisted               Unlisted
# 30                             Unlisted               Unlisted
# 31                             Unlisted               Unlisted
# 32                             Unlisted               Unlisted
# 33                             Unlisted               Unlisted
# 34                                  NaN                    NaN
# 35                             Unlisted               Unlisted
# 36                             Unlisted               Unlisted
# 37                             Unlisted               Unlisted
# 38                             Unlisted               Unlisted
# 39                                  NaN                    NaN
#
#    attributes.BYOBCorkage attributes.HairSpecializesIn attributes.DriveThru  \
# 0                Unlisted                     Unlisted             Unlisted
# 1                Unlisted                     Unlisted             Unlisted
# 2                Unlisted                     Unlisted             Unlisted
# 3                Unlisted                     Unlisted             Unlisted
# 4                Unlisted                     Unlisted             Unlisted
# 5                Unlisted                     Unlisted             Unlisted
# 6                Unlisted                     Unlisted             Unlisted
# 7                Unlisted                     Unlisted             Unlisted
# 8                Unlisted                     Unlisted             Unlisted
# 9                Unlisted                     Unlisted             Unlisted
# 10               Unlisted                     Unlisted             Unlisted
# 11               Unlisted                     Unlisted             Unlisted
# 12               Unlisted                     Unlisted             Unlisted
# 13               Unlisted                     Unlisted             Unlisted
# 14               Unlisted                     Unlisted             Unlisted
# 15               Unlisted                     Unlisted             Unlisted
# 16               Unlisted                     Unlisted             Unlisted
# 17               Unlisted                     Unlisted             Unlisted
# 18               Unlisted                     Unlisted             Unlisted
# 19               Unlisted                     Unlisted             Unlisted
# 20               Unlisted                     Unlisted             Unlisted
# 21               Unlisted                     Unlisted             Unlisted
# 22               Unlisted                     Unlisted             Unlisted
# 23               Unlisted                     Unlisted             Unlisted
# 24               Unlisted                     Unlisted             Unlisted
# 25               Unlisted                     Unlisted             Unlisted
# 26               Unlisted                     Unlisted             Unlisted
# 27               Unlisted                     Unlisted             Unlisted
# 28               Unlisted                     Unlisted             Unlisted
# 29               Unlisted                     Unlisted             Unlisted
# 30               Unlisted                     Unlisted             Unlisted
# 31               Unlisted                     Unlisted             Unlisted
# 32               Unlisted                     Unlisted             Unlisted
# 33               Unlisted                     Unlisted             Unlisted
# 34                    NaN                          NaN                  NaN
# 35               Unlisted                     Unlisted             Unlisted
# 36               Unlisted                     Unlisted             Unlisted
# 37               Unlisted                     Unlisted             Unlisted
# 38               Unlisted                     Unlisted             Unlisted
# 39                    NaN                          NaN                  NaN
#
#    attributes.Smoking                                   attributes.Music  \
# 0            Unlisted                                           Unlisted
# 1            Unlisted                                           Unlisted
# 2            Unlisted                                           Unlisted
# 3            Unlisted                                           Unlisted
# 4            Unlisted                                           Unlisted
# 5            Unlisted                                           Unlisted
# 6            Unlisted                                           Unlisted
# 7            Unlisted                                           Unlisted
# 8            Unlisted                                           Unlisted
# 9            Unlisted                                           Unlisted
# 10           Unlisted                                           Unlisted
# 11           Unlisted                                           Unlisted
# 12           Unlisted                                           Unlisted
# 13           Unlisted                                           Unlisted
# 14           Unlisted                                           Unlisted
# 15           Unlisted                                           Unlisted
# 16           Unlisted                                           Unlisted
# 17           Unlisted                                           Unlisted
# 18           Unlisted                                           Unlisted
# 19           Unlisted                                           Unlisted
# 20           Unlisted                                           Unlisted
# 21           Unlisted                                           Unlisted
# 22           Unlisted                                           Unlisted
# 23           Unlisted                                           Unlisted
# 24           Unlisted                                           Unlisted
# 25           Unlisted                                           Unlisted
# 26           Unlisted                                           Unlisted
# 27           Unlisted                                           Unlisted
# 28         u'outdoor'  {'dj': False, 'background_music': False, 'no_m...
# 29           Unlisted                                           Unlisted
# 30           Unlisted                                           Unlisted
# 31           Unlisted                                           Unlisted
# 32           Unlisted                                           Unlisted
# 33           Unlisted                                           Unlisted
# 34                NaN                                                NaN
# 35           Unlisted                                           Unlisted
# 36           Unlisted                                           Unlisted
# 37           Unlisted                                           Unlisted
# 38           Unlisted                                           Unlisted
# 39                NaN                                                NaN
#
#                                 attributes.BestNights  ...  \
# 0                                            Unlisted  ...
# 1                                            Unlisted  ...
# 2                                            Unlisted  ...
# 3                                            Unlisted  ...
# 4                                            Unlisted  ...
# 5                                            Unlisted  ...
# 6                                            Unlisted  ...
# 7                                            Unlisted  ...
# 8                                            Unlisted  ...
# 9                                            Unlisted  ...
# 10                                           Unlisted  ...
# 11                                           Unlisted  ...
# 12                                           Unlisted  ...
# 13                                           Unlisted  ...
# 14                                           Unlisted  ...
# 15                                           Unlisted  ...
# 16                                           Unlisted  ...
# 17                                           Unlisted  ...
# 18                                           Unlisted  ...
# 19                                           Unlisted  ...
# 20                                           Unlisted  ...
# 21                                           Unlisted  ...
# 22                                           Unlisted  ...
# 23                                           Unlisted  ...
# 24                                           Unlisted  ...
# 25                                           Unlisted  ...
# 26                                           Unlisted  ...
# 27                                           Unlisted  ...
# 28  {'monday': False, 'tuesday': True, 'friday': T...  ...
# 29                                           Unlisted  ...
# 30                                           Unlisted  ...
# 31                                           Unlisted  ...
# 32                                           Unlisted  ...
# 33                                           Unlisted  ...
# 34                                                NaN  ...
# 35                                           Unlisted  ...
# 36                                           Unlisted  ...
# 37                                           Unlisted  ...
# 38                                           Unlisted  ...
# 39                                                NaN  ...
#
#    attributes.RestaurantsTakeOut attributes.RestaurantsAttire attributes.WiFi  \
# 0                       Unlisted                     Unlisted        Unlisted
# 1                       Unlisted                     Unlisted        Unlisted
# 2                       Unlisted                     Unlisted        Unlisted
# 3                       Unlisted                     Unlisted        Unlisted
# 4                       Unlisted                     Unlisted           u'no'
# 5                       Unlisted                     Unlisted        Unlisted
# 6                           True                    u'casual'        Unlisted
# 7                       Unlisted                     Unlisted        Unlisted
# 8                           True                     Unlisted           u'no'
# 9                       Unlisted                     Unlisted        Unlisted
# 10                      Unlisted                     Unlisted        Unlisted
# 11                      Unlisted                     Unlisted        Unlisted
# 12                      Unlisted                     Unlisted        Unlisted
# 13                         False                     Unlisted        Unlisted
# 14                      Unlisted                     Unlisted        Unlisted
# 15                      Unlisted                     Unlisted        Unlisted
# 16                      Unlisted                     Unlisted        Unlisted
# 17                      Unlisted                     Unlisted        Unlisted
# 18                          True                    u'casual'        Unlisted
# 19                      Unlisted                     Unlisted        Unlisted
# 20                      Unlisted                     Unlisted        Unlisted
# 21                      Unlisted                     Unlisted        Unlisted
# 22                      Unlisted                     Unlisted        Unlisted
# 23                      Unlisted                     Unlisted        Unlisted
# 24                          True                     Unlisted           u'no'
# 25                      Unlisted                     Unlisted        Unlisted
# 26                          True                    u'casual'        Unlisted
# 27                      Unlisted                     Unlisted        Unlisted
# 28                      Unlisted                    u'casual'         u'free'
# 29                         False                    u'formal'           u'no'
# 30                      Unlisted                     Unlisted        Unlisted
# 31                      Unlisted                     Unlisted        Unlisted
# 32                         False                     Unlisted        Unlisted
# 33                      Unlisted                     Unlisted           u'no'
# 34                           NaN                          NaN             NaN
# 35                          True                     'casual'            'no'
# 36                      Unlisted                     Unlisted        Unlisted
# 37                      Unlisted                     Unlisted        Unlisted
# 38                      Unlisted                     Unlisted        Unlisted
# 39                           NaN                          NaN             NaN
#
#    attributes.RestaurantsPriceRange2 attributes.ByAppointmentOnly  \
# 0                                  3                        False
# 1                           Unlisted                         True
# 2                           Unlisted                         True
# 3                           Unlisted                     Unlisted
# 4                                  1                     Unlisted
# 5                           Unlisted                        False
# 6                                  1                        False
# 7                           Unlisted                     Unlisted
# 8                                  1                     Unlisted
# 9                           Unlisted                         True
# 10                          Unlisted                     Unlisted
# 11                          Unlisted                     Unlisted
# 12                          Unlisted                         True
# 13                                 2                     Unlisted
# 14                          Unlisted                     Unlisted
# 15                          Unlisted                     Unlisted
# 16                          Unlisted                     Unlisted
# 17                          Unlisted                     Unlisted
# 18                                 1                     Unlisted
# 19                          Unlisted                     Unlisted
# 20                                 2                        False
# 21                          Unlisted                         True
# 22                          Unlisted                     Unlisted
# 23                                 2                     Unlisted
# 24                          Unlisted                     Unlisted
# 25                          Unlisted                        False
# 26                                 1                     Unlisted
# 27                                 2                         True
# 28                          Unlisted                        False
# 29                                 4                     Unlisted
# 30                          Unlisted                     Unlisted
# 31                          Unlisted                        False
# 32                          Unlisted                        False
# 33                          Unlisted                        False
# 34                               NaN                          NaN
# 35                                 1                     Unlisted
# 36                          Unlisted                     Unlisted
# 37                          Unlisted                     Unlisted
# 38                                 3                     Unlisted
# 39                               NaN                          NaN
#
#                            attributes.BusinessParking attributes.GoodForKids  \
# 0   {'garage': False, 'street': False, 'validated'...                  False
# 1                                            Unlisted                   True
# 2                                            Unlisted               Unlisted
# 3                                            Unlisted               Unlisted
# 4   {'garage': False, 'street': False, 'validated'...               Unlisted
# 5                                            Unlisted               Unlisted
# 6                                                None                  False
# 7                                            Unlisted               Unlisted
# 8   {'garage': False, 'street': True, 'validated':...               Unlisted
# 9                                            Unlisted               Unlisted
# 10                                           Unlisted               Unlisted
# 11                                           Unlisted               Unlisted
# 12  {'garage': False, 'street': False, 'validated'...                   True
# 13  {'garage': False, 'street': False, 'validated'...                   True
# 14                                           Unlisted                   True
# 15                                           Unlisted               Unlisted
# 16                                           Unlisted               Unlisted
# 17                                           Unlisted               Unlisted
# 18  {'garage': False, 'street': False, 'validated'...                   True
# 19                                           Unlisted                   True
# 20  {'garage': False, 'street': False, 'validated'...               Unlisted
# 21                                           Unlisted               Unlisted
# 22                                           Unlisted               Unlisted
# 23  {'garage': False, 'street': False, 'validated'...               Unlisted
# 24                                               None               Unlisted
# 25                                           Unlisted               Unlisted
# 26  {'garage': False, 'street': False, 'validated'...                   True
# 27  {'garage': False, 'street': False, 'validated'...                   True
# 28  {'garage': False, 'street': False, 'validated'...                  False
# 29  {'garage': False, 'street': False, 'validated'...                   True
# 30  {'garage': False, 'street': False, 'validated'...               Unlisted
# 31  {'garage': False, 'street': False, 'validated'...                   True
# 32                                           Unlisted               Unlisted
# 33                                           Unlisted               Unlisted
# 34                                                NaN                    NaN
# 35  {'garage': False, 'street': False, 'validated'...                   True
# 36  {'garage': False, 'street': False, 'validated'...               Unlisted
# 37                                           Unlisted               Unlisted
# 38  {'garage': False, 'street': False, 'validated'...               Unlisted
# 39                                                NaN                    NaN
#
#    attributes.BikeParking attributes.BusinessAcceptsCreditCards  \
# 0                    True                                  True
# 1                Unlisted                              Unlisted
# 2                Unlisted                                  True
# 3                Unlisted                                  True
# 4                    True                                  True
# 5                Unlisted                                  True
# 6                   False                                  True
# 7                Unlisted                                  True
# 8                    True                                  True
# 9                Unlisted                                  True
# 10               Unlisted                                  True
# 11               Unlisted                                  True
# 12                   True                                  True
# 13                   True                                 False
# 14               Unlisted                              Unlisted
# 15               Unlisted                                  True
# 16               Unlisted                                  True
# 17               Unlisted                                  True
# 18                   True                                  True
# 19               Unlisted                                 False
# 20                   True                                  True
# 21               Unlisted                              Unlisted
# 22               Unlisted                                  True
# 23               Unlisted                                  True
# 24                   True                                  True
# 25               Unlisted                              Unlisted
# 26               Unlisted                                  True
# 27               Unlisted                                 False
# 28                  False                                  True
# 29                  False                                 False
# 30               Unlisted                                  True
# 31                   True                                  True
# 32               Unlisted                                  True
# 33               Unlisted                                  True
# 34                    NaN                                   NaN
# 35                   True                                  True
# 36               Unlisted                              Unlisted
# 37               Unlisted                                  True
# 38                  False                                  True
# 39                    NaN                                   NaN
#
#    attributes.RestaurantsPriceRange
# 0                                 3
# 1                          Unlisted
# 2                          Unlisted
# 3                          Unlisted
# 4                                 1
# 5                          Unlisted
# 6                                 1
# 7                          Unlisted
# 8                                 1
# 9                          Unlisted
# 10                         Unlisted
# 11                         Unlisted
# 12                         Unlisted
# 13                                2
# 14                         Unlisted
# 15                         Unlisted
# 16                         Unlisted
# 17                         Unlisted
# 18                                1
# 19                         Unlisted
# 20                                2
# 21                         Unlisted
# 22                         Unlisted
# 23                                2
# 24                         Unlisted
# 25                         Unlisted
# 26                                1
# 27                                2
# 28                         Unlisted
# 29                                4
# 30                         Unlisted
# 31                         Unlisted
# 32                         Unlisted
# 33                         Unlisted
# 34                              NaN
# 35                                1
# 36                         Unlisted
# 37                         Unlisted
# 38                                3
# 39                              NaN
#
# [40 rows x 40 columns]

# %%
#Make sure NaNs in rows where the dictionary did not exist were not overwritten
attributes[attributes.isna().any(axis=1)]
# Out:
#        attributes.Open24Hours attributes.DietaryRestrictions  \
# 34                        NaN                            NaN
# 39                        NaN                            NaN
# 57                        NaN                            NaN
# 68                        NaN                            NaN
# 71                        NaN                            NaN
# ...                       ...                            ...
# 124846                    NaN                            NaN
# 124867                    NaN                            NaN
# 124874                    NaN                            NaN
# 124879                    NaN                            NaN
# 124890                    NaN                            NaN
#
#        attributes.RestaurantsCounterService attributes.AgesAllowed  \
# 34                                      NaN                    NaN
# 39                                      NaN                    NaN
# 57                                      NaN                    NaN
# 68                                      NaN                    NaN
# 71                                      NaN                    NaN
# ...                                     ...                    ...
# 124846                                  NaN                    NaN
# 124867                                  NaN                    NaN
# 124874                                  NaN                    NaN
# 124879                                  NaN                    NaN
# 124890                                  NaN                    NaN
#
#        attributes.BYOBCorkage attributes.HairSpecializesIn  \
# 34                        NaN                          NaN
# 39                        NaN                          NaN
# 57                        NaN                          NaN
# 68                        NaN                          NaN
# 71                        NaN                          NaN
# ...                       ...                          ...
# 124846                    NaN                          NaN
# 124867                    NaN                          NaN
# 124874                    NaN                          NaN
# 124879                    NaN                          NaN
# 124890                    NaN                          NaN
#
#        attributes.DriveThru attributes.Smoking attributes.Music  \
# 34                      NaN                NaN              NaN
# 39                      NaN                NaN              NaN
# 57                      NaN                NaN              NaN
# 68                      NaN                NaN              NaN
# 71                      NaN                NaN              NaN
# ...                     ...                ...              ...
# 124846                  NaN                NaN              NaN
# 124867                  NaN                NaN              NaN
# 124874                  NaN                NaN              NaN
# 124879                  NaN                NaN              NaN
# 124890                  NaN                NaN              NaN
#
#        attributes.BestNights  ... attributes.RestaurantsTakeOut  \
# 34                       NaN  ...                           NaN
# 39                       NaN  ...                           NaN
# 57                       NaN  ...                           NaN
# 68                       NaN  ...                           NaN
# 71                       NaN  ...                           NaN
# ...                      ...  ...                           ...
# 124846                   NaN  ...                           NaN
# 124867                   NaN  ...                           NaN
# 124874                   NaN  ...                           NaN
# 124879                   NaN  ...                           NaN
# 124890                   NaN  ...                           NaN
#
#        attributes.RestaurantsAttire attributes.WiFi  \
# 34                              NaN             NaN
# 39                              NaN             NaN
# 57                              NaN             NaN
# 68                              NaN             NaN
# 71                              NaN             NaN
# ...                             ...             ...
# 124846                          NaN             NaN
# 124867                          NaN             NaN
# 124874                          NaN             NaN
# 124879                          NaN             NaN
# 124890                          NaN             NaN
#
#        attributes.RestaurantsPriceRange2 attributes.ByAppointmentOnly  \
# 34                                   NaN                          NaN
# 39                                   NaN                          NaN
# 57                                   NaN                          NaN
# 68                                   NaN                          NaN
# 71                                   NaN                          NaN
# ...                                  ...                          ...
# 124846                               NaN                          NaN
# 124867                               NaN                          NaN
# 124874                               NaN                          NaN
# 124879                               NaN                          NaN
# 124890                               NaN                          NaN
#
#        attributes.BusinessParking attributes.GoodForKids  \
# 34                            NaN                    NaN
# 39                            NaN                    NaN
# 57                            NaN                    NaN
# 68                            NaN                    NaN
# 71                            NaN                    NaN
# ...                           ...                    ...
# 124846                        NaN                    NaN
# 124867                        NaN                    NaN
# 124874                        NaN                    NaN
# 124879                        NaN                    NaN
# 124890                        NaN                    NaN
#
#        attributes.BikeParking attributes.BusinessAcceptsCreditCards  \
# 34                        NaN                                   NaN
# 39                        NaN                                   NaN
# 57                        NaN                                   NaN
# 68                        NaN                                   NaN
# 71                        NaN                                   NaN
# ...                       ...                                   ...
# 124846                    NaN                                   NaN
# 124867                    NaN                                   NaN
# 124874                    NaN                                   NaN
# 124879                    NaN                                   NaN
# 124890                    NaN                                   NaN
#
#        attributes.RestaurantsPriceRange
# 34                                  NaN
# 39                                  NaN
# 57                                  NaN
# 68                                  NaN
# 71                                  NaN
# ...                                 ...
# 124846                              NaN
# 124867                              NaN
# 124874                              NaN
# 124879                              NaN
# 124890                              NaN
#
# [17828 rows x 40 columns]

# %%
#selecting desired attributes
desired_attributes = attributes[['attributes.HappyHour', 'attributes.GoodForDancing', 'attributes.WheelchairAccessible', 'attributes.RestaurantsDelivery', 'attributes.RestaurantsTakeOut', 'attributes.RestaurantsPriceRange', 'attributes.Alcohol', 'attributes.DogsAllowed', 'attributes.GoodForKids', 'attributes.BikeParking']]

# %%
desired_attributes.info()
desired_attributes.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124891 entries, 0 to 124890
# Data columns (total 10 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   attributes.HappyHour              107063 non-null  object
#  1   attributes.GoodForDancing         107063 non-null  object
#  2   attributes.WheelchairAccessible   107063 non-null  object
#  3   attributes.RestaurantsDelivery    107063 non-null  object
#  4   attributes.RestaurantsTakeOut     107063 non-null  object
#  5   attributes.RestaurantsPriceRange  107063 non-null  object
#  6   attributes.Alcohol                107063 non-null  object
#  7   attributes.DogsAllowed            107063 non-null  object
#  8   attributes.GoodForKids            107063 non-null  object
#  9   attributes.BikeParking            107063 non-null  object
# dtypes: object(10)
# memory usage: 9.5+ MB
#   attributes.HappyHour attributes.GoodForDancing  \
# 0             Unlisted                  Unlisted
# 1             Unlisted                  Unlisted
# 2             Unlisted                  Unlisted
# 3             Unlisted                  Unlisted
# 4             Unlisted                  Unlisted
#
#   attributes.WheelchairAccessible attributes.RestaurantsDelivery  \
# 0                        Unlisted                       Unlisted
# 1                        Unlisted                       Unlisted
# 2                        Unlisted                       Unlisted
# 3                        Unlisted                       Unlisted
# 4                        Unlisted                       Unlisted
#
#   attributes.RestaurantsTakeOut attributes.RestaurantsPriceRange  \
# 0                      Unlisted                                3
# 1                      Unlisted                         Unlisted
# 2                      Unlisted                         Unlisted
# 3                      Unlisted                         Unlisted
# 4                      Unlisted                                1
#
#   attributes.Alcohol attributes.DogsAllowed attributes.GoodForKids  \
# 0           Unlisted               Unlisted                  False
# 1           Unlisted               Unlisted                   True
# 2           Unlisted               Unlisted               Unlisted
# 3           Unlisted               Unlisted               Unlisted
# 4           Unlisted               Unlisted               Unlisted
#
#   attributes.BikeParking
# 0                   True
# 1               Unlisted
# 2               Unlisted
# 3               Unlisted
# 4                   True

# %% [markdown]
# There are some other potentially useful attributes that contain their own nested dictionaries. In order to not blow our table up too much with sparse data, we are going to include the full attributes json and and try to handle these through NoSQL for now. If we find they are popular queries, we will go back and expand them into relational columns. These are some of those attributes, along with their first non-null row, so we can get an idea of their keys.

# %%
#make another attributes to let us dirtily look at nested content
attributes2 = yelp_flat.filter(regex='^attributes.',axis=1)

# %%
att = attributes2['attributes.Music']
att.loc[att.first_valid_index()]
# Out:
# "{'dj': False, 'background_music': False, 'no_music': False, 'jukebox': False, 'live': True, 'video': False, 'karaoke': False}"

# %%
att = attributes2['attributes.GoodForMeal']
att.loc[att.first_valid_index()]
# Out:
# "{'dessert': False, 'latenight': False, 'lunch': False, 'dinner': False, 'brunch': False, 'breakfast': False}"

# %%
att = attributes2['attributes.Ambience']
att.loc[att.first_valid_index()]
# Out:
# "{'romantic': False, 'intimate': False, 'touristy': False, 'hipster': False, 'divey': False, 'classy': False, 'trendy': False, 'upscale': False, 'casual': False}"

# %%
att = attributes2['attributes.BusinessParking']
att.loc[att.first_valid_index()]
# Out:
# "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}"

# %%
#drop all attributes from original df, then add back just the desired ones
final_cols = [col for col in yelp_flat.columns if not col.startswith('attributes.')]
yelp_final = yelp_flat[final_cols]
yelp_final = pd.concat([yelp_final, desired_attributes], join='inner', axis=1)
yelp_final.info()
yelp_final.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124891 entries, 0 to 124890
# Data columns (total 33 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   business_id                       124891 non-null  object
#  1   name                              124891 non-null  object
#  2   city                              124891 non-null  object
#  3   state                             124891 non-null  object
#  4   postal_code                       124891 non-null  float64
#  5   latitude                          124891 non-null  float64
#  6   longitude                         124891 non-null  float64
#  7   stars                             124891 non-null  float64
#  8   review_count                      124891 non-null  int64
#  9   hours.Sunday_open                 103793 non-null  object
#  10  hours.Sunday_closed               103793 non-null  object
#  11  hours.Saturday_open               103793 non-null  object
#  12  hours.Saturday_closed             103793 non-null  object
#  13  hours.Monday_open                 103793 non-null  object
#  14  hours.Monday_closed               103793 non-null  object
#  15  hours.Tuesday_open                103793 non-null  object
#  16  hours.Tuesday_closed              103793 non-null  object
#  17  hours.Wednesday_open              103793 non-null  object
#  18  hours.Wednesday_closed            103793 non-null  object
#  19  hours.Thursday_open               103793 non-null  object
#  20  hours.Thursday_closed             103793 non-null  object
#  21  hours.Friday_open                 103793 non-null  object
#  22  hours.Friday_closed               103793 non-null  object
#  23  attributes.HappyHour              107063 non-null  object
#  24  attributes.GoodForDancing         107063 non-null  object
#  25  attributes.WheelchairAccessible   107063 non-null  object
#  26  attributes.RestaurantsDelivery    107063 non-null  object
#  27  attributes.RestaurantsTakeOut     107063 non-null  object
#  28  attributes.RestaurantsPriceRange  107063 non-null  object
#  29  attributes.Alcohol                107063 non-null  object
#  30  attributes.DogsAllowed            107063 non-null  object
#  31  attributes.GoodForKids            107063 non-null  object
#  32  attributes.BikeParking            107063 non-null  object
# dtypes: float64(4), int64(1), object(28)
# memory usage: 31.4+ MB
#               business_id                         name        city state  \
# 0  f9NumwFMBDn751xgFiRbNA     The Range At Lake Norman   Cornelius    NC
# 1  Yzvjg0SayhoZgCljUJRF9Q            Carlos Santo, NMD  Scottsdale    AZ
# 2  51M2Kk903DFYI6gnB5I6SQ      USE MY GUY SERVICES LLC        Mesa    AZ
# 3  cKyLV5oWZJ2NudWgqs8VZw  Oasis Auto Center - Gilbert     Gilbert    AZ
# 4  oiAlXZPIFm2nBCt0DHLu_Q         Green World Cleaners   Las Vegas    NV
#
#    postal_code   latitude   longitude  stars  review_count hours.Sunday_open  \
# 0      28031.0  35.462724  -80.852612    3.5            36              13:0
# 1      85258.0  33.569404 -111.890264    5.0             4               NaN
# 2      85205.0  33.428065 -111.726648    4.5            26            Closed
# 3      85233.0  33.350399 -111.827142    4.5            38            Closed
# 4      89118.0  36.063977 -115.241463    3.5            81            Closed
#
#    ... attributes.HappyHour attributes.GoodForDancing  \
# 0  ...             Unlisted                  Unlisted
# 1  ...             Unlisted                  Unlisted
# 2  ...             Unlisted                  Unlisted
# 3  ...             Unlisted                  Unlisted
# 4  ...             Unlisted                  Unlisted
#
#   attributes.WheelchairAccessible attributes.RestaurantsDelivery  \
# 0                        Unlisted                       Unlisted
# 1                        Unlisted                       Unlisted
# 2                        Unlisted                       Unlisted
# 3                        Unlisted                       Unlisted
# 4                        Unlisted                       Unlisted
#
#   attributes.RestaurantsTakeOut attributes.RestaurantsPriceRange  \
# 0                      Unlisted                                3
# 1                      Unlisted                         Unlisted
# 2                      Unlisted                         Unlisted
# 3                      Unlisted                         Unlisted
# 4                      Unlisted                                1
#
#   attributes.Alcohol attributes.DogsAllowed attributes.GoodForKids  \
# 0           Unlisted               Unlisted                  False
# 1           Unlisted               Unlisted                   True
# 2           Unlisted               Unlisted               Unlisted
# 3           Unlisted               Unlisted               Unlisted
# 4           Unlisted               Unlisted               Unlisted
#
#   attributes.BikeParking
# 0                   True
# 1               Unlisted
# 2               Unlisted
# 3               Unlisted
# 4                   True
#
# [5 rows x 33 columns]

# %% [markdown]
# Of our included attributes, we have two that are not boolean (Alcohol and RestaurantsPriceRange). These are the values for those two:

# %%
att = yelp_final['attributes.Alcohol']
att.value_counts()
# Out:
# Unlisted            84860
# u'none'              7605
# u'full_bar'          6464
# 'none'               3297
# u'beer_and_wine'     2089
# 'full_bar'           1820
# 'beer_and_wine'       912
# None                   16
# Name: attributes.Alcohol, dtype: int64

# %%
att = yelp_final['attributes.RestaurantsPriceRange']
att.value_counts()
# Out:
# Unlisted    52101
# 2           29969
# 1           19616
# 3            4263
# 4            1081
# None           33
# Name: attributes.RestaurantsPriceRange, dtype: int64

# %% [markdown]
# Price range is fine to leave as is (though we might want to include dollar signs in our front-end js), but Alcohol has an interesting phenomenon where there are duplicate row values with a 'u' prefix. We believe this is to signify that such a quality was determined by users rather than listed by the business. For our purposes, however, that seems a little to granular, so let's group user and business ratings together. There's also a 'none', which is likely a specific listing that no alcohol is offered, and a None, which might represent nothing being listed. However the latter only has 21 values, so for our sake it is probably safe to merge these as well.

# %%
yelp_final['attributes.Alcohol'].replace("u'none'", "None", inplace=True)
yelp_final['attributes.Alcohol'].replace("'none'", "None", inplace=True)
yelp_final['attributes.Alcohol'].replace("u'full_bar'", "full_bar", inplace=True)
yelp_final['attributes.Alcohol'].replace("u'beer_and_wine'", "beer_and_wine", inplace=True)
yelp_final['attributes.Alcohol'].replace("'full_bar'", "full_bar", inplace=True)
yelp_final['attributes.Alcohol'].replace("'beer_and_wine'", "beer_and_wine", inplace=True)

yelp_final['attributes.Alcohol'].value_counts()
# Out:
# Unlisted         84860
# None             10918
# full_bar          8284
# beer_and_wine     3001
# Name: attributes.Alcohol, dtype: int64

# %%
yelp_final = pd.concat([yelp_final,yelp_reduced['attributes']], join='inner', axis=1)

yelp_final.info()
yelp_final.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124891 entries, 0 to 124890
# Data columns (total 34 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   business_id                       124891 non-null  object
#  1   name                              124891 non-null  object
#  2   city                              124891 non-null  object
#  3   state                             124891 non-null  object
#  4   postal_code                       124891 non-null  float64
#  5   latitude                          124891 non-null  float64
#  6   longitude                         124891 non-null  float64
#  7   stars                             124891 non-null  float64
#  8   review_count                      124891 non-null  int64
#  9   hours.Sunday_open                 103793 non-null  object
#  10  hours.Sunday_closed               103793 non-null  object
#  11  hours.Saturday_open               103793 non-null  object
#  12  hours.Saturday_closed             103793 non-null  object
#  13  hours.Monday_open                 103793 non-null  object
#  14  hours.Monday_closed               103793 non-null  object
#  15  hours.Tuesday_open                103793 non-null  object
#  16  hours.Tuesday_closed              103793 non-null  object
#  17  hours.Wednesday_open              103793 non-null  object
#  18  hours.Wednesday_closed            103793 non-null  object
#  19  hours.Thursday_open               103793 non-null  object
#  20  hours.Thursday_closed             103793 non-null  object
#  21  hours.Friday_open                 103793 non-null  object
#  22  hours.Friday_closed               103793 non-null  object
#  23  attributes.HappyHour              107063 non-null  object
#  24  attributes.GoodForDancing         107063 non-null  object
#  25  attributes.WheelchairAccessible   107063 non-null  object
#  26  attributes.RestaurantsDelivery    107063 non-null  object
#  27  attributes.RestaurantsTakeOut     107063 non-null  object
#  28  attributes.RestaurantsPriceRange  107063 non-null  object
#  29  attributes.Alcohol                107063 non-null  object
#  30  attributes.DogsAllowed            107063 non-null  object
#  31  attributes.GoodForKids            107063 non-null  object
#  32  attributes.BikeParking            107063 non-null  object
#  33  attributes                        107064 non-null  object
# dtypes: float64(4), int64(1), object(29)
# memory usage: 32.4+ MB
#               business_id                         name        city state  \
# 0  f9NumwFMBDn751xgFiRbNA     The Range At Lake Norman   Cornelius    NC
# 1  Yzvjg0SayhoZgCljUJRF9Q            Carlos Santo, NMD  Scottsdale    AZ
# 2  51M2Kk903DFYI6gnB5I6SQ      USE MY GUY SERVICES LLC        Mesa    AZ
# 3  cKyLV5oWZJ2NudWgqs8VZw  Oasis Auto Center - Gilbert     Gilbert    AZ
# 4  oiAlXZPIFm2nBCt0DHLu_Q         Green World Cleaners   Las Vegas    NV
#
#    postal_code   latitude   longitude  stars  review_count hours.Sunday_open  \
# 0      28031.0  35.462724  -80.852612    3.5            36              13:0
# 1      85258.0  33.569404 -111.890264    5.0             4               NaN
# 2      85205.0  33.428065 -111.726648    4.5            26            Closed
# 3      85233.0  33.350399 -111.827142    4.5            38            Closed
# 4      89118.0  36.063977 -115.241463    3.5            81            Closed
#
#    ... attributes.GoodForDancing attributes.WheelchairAccessible  \
# 0  ...                  Unlisted                        Unlisted
# 1  ...                  Unlisted                        Unlisted
# 2  ...                  Unlisted                        Unlisted
# 3  ...                  Unlisted                        Unlisted
# 4  ...                  Unlisted                        Unlisted
#
#   attributes.RestaurantsDelivery attributes.RestaurantsTakeOut  \
# 0                       Unlisted                      Unlisted
# 1                       Unlisted                      Unlisted
# 2                       Unlisted                      Unlisted
# 3                       Unlisted                      Unlisted
# 4                       Unlisted                      Unlisted
#
#   attributes.RestaurantsPriceRange attributes.Alcohol attributes.DogsAllowed  \
# 0                                3           Unlisted               Unlisted
# 1                         Unlisted           Unlisted               Unlisted
# 2                         Unlisted           Unlisted               Unlisted
# 3                         Unlisted           Unlisted               Unlisted
# 4                                1           Unlisted               Unlisted
#
#   attributes.GoodForKids attributes.BikeParking  \
# 0                  False                   True
# 1                   True               Unlisted
# 2               Unlisted               Unlisted
# 3               Unlisted               Unlisted
# 4               Unlisted                   True
#
#                                           attributes
# 0  {'BusinessAcceptsCreditCards': 'True', 'BikePa...
# 1  {'GoodForKids': 'True', 'ByAppointmentOnly': '...
# 2  {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 3             {'BusinessAcceptsCreditCards': 'True'}
# 4  {'BusinessParking': '{'garage': False, 'street...
#
# [5 rows x 34 columns]

# %%
yelp_final['attributes.RestaurantsPriceRange'].value_counts()
# Out:
# Unlisted    52101
# 2           29969
# 1           19616
# 3            4263
# 4            1081
# None           33
# Name: attributes.RestaurantsPriceRange, dtype: int64

# %%
yelp_final.to_csv('yelp_main.csv', index = False)

# %%
# No attributes-json included

yelp_final.drop('attributes', axis=1, inplace =True)

# %%
#Replace commas before saving to csv so they don't get misinterpreted
#After exploration, only 'name' has commas
yelp_final['name'] = yelp_final['name'].apply(lambda x: x.replace(',', '.'))

# %%
print(yelp_final[yelp_final['name'].str.contains(',')])
# Out:
# Empty DataFrame
# Columns: [business_id, name, city, state, postal_code, latitude, longitude, stars, review_count, hours.Sunday_open, hours.Sunday_closed, hours.Saturday_open, hours.Saturday_closed, hours.Monday_open, hours.Monday_closed, hours.Tuesday_open, hours.Tuesday_closed, hours.Wednesday_open, hours.Wednesday_closed, hours.Thursday_open, hours.Thursday_closed, hours.Friday_open, hours.Friday_closed, attributes.HappyHour, attributes.GoodForDancing, attributes.WheelchairAccessible, attributes.RestaurantsDelivery, attributes.RestaurantsTakeOut, attributes.RestaurantsPriceRange, attributes.Alcohol, attributes.DogsAllowed, attributes.GoodForKids, attributes.BikeParking]
# Index: []
#
# [0 rows x 33 columns]

# %%
yelp_final.head()
# Out:
#               business_id                         name        city state  \
# 0  f9NumwFMBDn751xgFiRbNA     The Range At Lake Norman   Cornelius    NC
# 1  Yzvjg0SayhoZgCljUJRF9Q            Carlos Santo. NMD  Scottsdale    AZ
# 2  51M2Kk903DFYI6gnB5I6SQ      USE MY GUY SERVICES LLC        Mesa    AZ
# 3  cKyLV5oWZJ2NudWgqs8VZw  Oasis Auto Center - Gilbert     Gilbert    AZ
# 4  oiAlXZPIFm2nBCt0DHLu_Q         Green World Cleaners   Las Vegas    NV
#
#    postal_code   latitude   longitude  stars  review_count hours.Sunday_open  \
# 0      28031.0  35.462724  -80.852612    3.5            36              13:0
# 1      85258.0  33.569404 -111.890264    5.0             4               NaN
# 2      85205.0  33.428065 -111.726648    4.5            26            Closed
# 3      85233.0  33.350399 -111.827142    4.5            38            Closed
# 4      89118.0  36.063977 -115.241463    3.5            81            Closed
#
#    ... attributes.HappyHour attributes.GoodForDancing  \
# 0  ...             Unlisted                  Unlisted
# 1  ...             Unlisted                  Unlisted
# 2  ...             Unlisted                  Unlisted
# 3  ...             Unlisted                  Unlisted
# 4  ...             Unlisted                  Unlisted
#
#   attributes.WheelchairAccessible attributes.RestaurantsDelivery  \
# 0                        Unlisted                       Unlisted
# 1                        Unlisted                       Unlisted
# 2                        Unlisted                       Unlisted
# 3                        Unlisted                       Unlisted
# 4                        Unlisted                       Unlisted
#
#   attributes.RestaurantsTakeOut attributes.RestaurantsPriceRange  \
# 0                      Unlisted                                3
# 1                      Unlisted                         Unlisted
# 2                      Unlisted                         Unlisted
# 3                      Unlisted                         Unlisted
# 4                      Unlisted                                1
#
#   attributes.Alcohol attributes.DogsAllowed attributes.GoodForKids  \
# 0           Unlisted               Unlisted                  False
# 1           Unlisted               Unlisted                   True
# 2           Unlisted               Unlisted               Unlisted
# 3           Unlisted               Unlisted               Unlisted
# 4           Unlisted               Unlisted               Unlisted
#
#   attributes.BikeParking
# 0                   True
# 1               Unlisted
# 2               Unlisted
# 3               Unlisted
# 4                   True
#
# [5 rows x 33 columns]

# %%
yelp_final.to_csv('yelp_main_nojson.csv', index = False)

# %% [markdown]
# ## Categories

# %% [markdown]
# Now we'll deal with categories

# %%
#First, split comma separated string into list
categories['categories'] = categories['categories'].apply(lambda x: x.split(','))

# %% [markdown]
# We will have a grouping issue, since some words for each category string will start the string, while some will follow a comma and thus have a leading space. Let's strip all the tags of leading and trailing whitespace

# %%
def strip_tags(tag_list):
    return [tag.strip() for tag in tag_list]

# %%
categories['categories'] = categories['categories'].apply(lambda x: strip_tags(x))
categories.head()
# Out:
#               business_id                                         categories
# 0  f9NumwFMBDn751xgFiRbNA  [Active Life, Gun/Rifle Ranges, Guns & Ammo, S...
# 1  Yzvjg0SayhoZgCljUJRF9Q  [Health & Medical, Fitness & Instruction, Yoga...
# 2  51M2Kk903DFYI6gnB5I6SQ  [Home Services, Plumbing, Electricians, Handym...
# 3  cKyLV5oWZJ2NudWgqs8VZw  [Auto Repair, Automotive, Oil Change Stations,...
# 4  oiAlXZPIFm2nBCt0DHLu_Q  [Dry Cleaning & Laundry, Local Services, Laund...

# %%
#Explode categories into new rows
categories_exploded = categories.explode('categories')
categories_exploded.info()
categories_exploded.head(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 543127 entries, 0 to 124891
# Data columns (total 2 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   business_id  543127 non-null  object
#  1   categories   543127 non-null  object
# dtypes: object(2)
# memory usage: 12.4+ MB
#               business_id              categories
# 0  f9NumwFMBDn751xgFiRbNA             Active Life
# 0  f9NumwFMBDn751xgFiRbNA        Gun/Rifle Ranges
# 0  f9NumwFMBDn751xgFiRbNA             Guns & Ammo
# 0  f9NumwFMBDn751xgFiRbNA                Shopping
# 1  Yzvjg0SayhoZgCljUJRF9Q        Health & Medical
# 1  Yzvjg0SayhoZgCljUJRF9Q   Fitness & Instruction
# 1  Yzvjg0SayhoZgCljUJRF9Q                    Yoga
# 1  Yzvjg0SayhoZgCljUJRF9Q             Active Life
# 1  Yzvjg0SayhoZgCljUJRF9Q                 Pilates
# 2  51M2Kk903DFYI6gnB5I6SQ           Home Services
# 2  51M2Kk903DFYI6gnB5I6SQ                Plumbing
# 2  51M2Kk903DFYI6gnB5I6SQ            Electricians
# 2  51M2Kk903DFYI6gnB5I6SQ                Handyman
# 2  51M2Kk903DFYI6gnB5I6SQ             Contractors
# 3  cKyLV5oWZJ2NudWgqs8VZw             Auto Repair
# 3  cKyLV5oWZJ2NudWgqs8VZw              Automotive
# 3  cKyLV5oWZJ2NudWgqs8VZw     Oil Change Stations
# 3  cKyLV5oWZJ2NudWgqs8VZw     Transmission Repair
# 4  oiAlXZPIFm2nBCt0DHLu_Q  Dry Cleaning & Laundry
# 4  oiAlXZPIFm2nBCt0DHLu_Q          Local Services

# %%
categories_exploded['categories'].value_counts()
# Out:
# Restaurants            25765
# Shopping               21495
# Home Services          18841
# Food                   15489
# Health & Medical       15187
#                        ...
# Ceremonial Clothing        1
# Bungee Jumping             1
# Speech Training            1
# Street Art                 1
# Bus Stations               1
# Name: categories, Length: 1296, dtype: int64

# %%
categories_exploded.max()
# Out:
# business_id    zzwicjPC9g246MK2M1ZFBA
# categories                       Zoos
# dtype: object

# %%
categories_exploded.min()
# Out:
# business_id    --7zmmkVg-IMGaXbuVd0SQ
# categories                 & Probates
# dtype: object

# %%
categories_exploded.sort_values('categories')['categories'].unique()
# Out:
# array(['& Probates', '3D Printing', 'ATV Rentals/Tours', ..., 'Yoga',
#        'Ziplining', 'Zoos'], dtype=object)

# %%
categories_exploded.sort_values('categories')['categories'].nunique()
# Out:
# 1296

# %% [markdown]
# It looks like we have one funky tag: & Probates. Upon further inspection, it seems that this comes from the fact that one of the tags includes commas ('Wills, Trusts, & Probates'). If there were a ton of these, that might be cause for concern, as there is not really a regex function we could use to find all of those without knowing the number antecedents). Luckily, it's just the one though (as we could tell by sorting the values and seeing there are no more that start with an &). Let's combine those together

# %%
categories_exploded[categories_exploded.duplicated()]
# Out:
#                    business_id    categories
# 3342    HEGy1__jKyMhkhXRW3O1ZQ  Gas Stations
# 3992    DppMDrrAE3eWkD3JE7gl7g  Gas Stations
# 5607    PSrITKG8En8mvwZ_YhywTg  Gas Stations
# 5890    nY9ZcdrkncyVh3ZJ4WvtwA  Gas Stations
# 8455    KoOqNG0ysV8yChCf5-XE0Q  Gas Stations
# ...                        ...           ...
# 115220  0HDUNUvva3BEC1Yfe9an5A  Gas Stations
# 117143  mlkVAm2DkGnKnNVR1AnQLA  Gas Stations
# 117596  NQauHAQNg_a0z8WndFY3Wg  Gas Stations
# 120090  Mxn7K5xv7xXukrh10y8crg  Gas Stations
# 121997  mBv6NDaN1HXEpSP9zmOyXQ  Gas Stations
#
# [84 rows x 2 columns]

# %% [markdown]
# Somehow Gas Stations got duplicated- that's probably safe to just drop_duplicates

# %%
categories_exploded['categories'].replace('Wills', 'Wills, Trusts, & Probates', inplace=True)
categories_exploded['categories'].replace('Trusts', 'Wills, Trusts, & Probates', inplace=True)
categories_exploded['categories'].replace(' & Probates', 'Wills, Trusts, & Probates', inplace=True)

#delete duplicates
categories_exploded.drop_duplicates(inplace=True)

# %%
categories_exploded.sort_values('categories')['categories'].unique()
# Out:
# array(['& Probates', '3D Printing', 'ATV Rentals/Tours', ..., 'Yoga',
#        'Ziplining', 'Zoos'], dtype=object)

# %%
categories_exploded[categories_exploded['categories'] == 'Wills, Trusts, & Probates']
# Out:
#                    business_id                 categories
# 2869    gFtYRB0AVTrakzNBgbq4nQ  Wills, Trusts, & Probates
# 6202    tNlfh4x5HUUHj65KbNmDFg  Wills, Trusts, & Probates
# 6354    GeVgX-OZDTlOskU9kd8TuA  Wills, Trusts, & Probates
# 6627    7RMJmOFSG3aSXU83KBoWGg  Wills, Trusts, & Probates
# 8580    BY9IQn3lvx6UGnPQQHAusQ  Wills, Trusts, & Probates
# ...                        ...                        ...
# 121126  fxkqaZgPUVrs1Tgdnrec1w  Wills, Trusts, & Probates
# 121229  T23Z6F4l0j-qriMSlyYTLA  Wills, Trusts, & Probates
# 121608  81H_yEsSDHcy2rXZ7EwsZw  Wills, Trusts, & Probates
# 122367  7YOEPQdMWGbKsat7xTeDwg  Wills, Trusts, & Probates
# 124248  Vg9c5JeXkYpJh_bS6sH0tA  Wills, Trusts, & Probates
#
# [107 rows x 2 columns]

# %%
categories_exploded.duplicated().sum()
# Out:
# 0

# %%
cat_set = set(categories_exploded['categories'])

# %%
#check out tags to see any blatant similarities
sorted(cat_set)
# Out:
# ['& Probates',
#  '3D Printing',
#  'ATV Rentals/Tours',
#  'Acai Bowls',
#  'Accessories',
#  'Accountants',
#  'Acne Treatment',
#  'Active Life',
#  'Acupuncture',
#  'Addiction Medicine',
#  'Adoption Services',
#  'Adult',
#  'Adult Education',
#  'Adult Entertainment',
#  'Advertising',
#  'Aerial Fitness',
#  'Aerial Tours',
#  'Aestheticians',
#  'Afghan',
#  'African',
#  'Air Duct Cleaning',
#  'Aircraft Dealers',
#  'Aircraft Repairs',
#  'Airlines',
#  'Airport Lounges',
#  'Airport Shuttles',
#  'Airport Terminals',
#  'Airports',
#  'Airsoft',
#  'Allergists',
#  'Alternative Medicine',
#  'Amateur Sports Teams',
#  'American (New)',
#  'American (Traditional)',
#  'Amusement Parks',
#  'Anesthesiologists',
#  'Animal Assisted Therapy',
#  'Animal Physical Therapy',
#  'Animal Shelters',
#  'Antiques',
#  'Apartment Agents',
#  'Apartments',
#  'Appliances',
#  'Appliances & Repair',
#  'Appraisal Services',
#  'Aquarium Services',
#  'Aquariums',
#  'Arabian',
#  'Arcades',
#  'Archery',
#  'Architects',
#  'Architectural Tours',
#  'Argentine',
#  'Armenian',
#  'Art Classes',
#  'Art Consultants',
#  'Art Galleries',
#  'Art Installation',
#  'Art Museums',
#  'Art Restoration',
#  'Art Schools',
#  'Art Space Rentals',
#  'Art Supplies',
#  'Art Tours',
#  'Artificial Turf',
#  'Arts & Crafts',
#  'Arts & Entertainment',
#  'Asian Fusion',
#  'Assisted Living Facilities',
#  'Astrologers',
#  'Attraction Farms',
#  'Auction Houses',
#  'Audio/Visual Equipment Rental',
#  'Audiologist',
#  'Austrian',
#  'Auto Customization',
#  'Auto Detailing',
#  'Auto Electric Services',
#  'Auto Glass Services',
#  'Auto Insurance',
#  'Auto Loan Providers',
#  'Auto Parts & Supplies',
#  'Auto Repair',
#  'Auto Security',
#  'Auto Upholstery',
#  'Automotive',
#  'Aviation Services',
#  'Awnings',
#  'Axe Throwing',
#  'Ayurveda',
#  'Baby Gear & Furniture',
#  'Backflow Services',
#  'Badminton',
#  'Bagels',
#  'Bail Bondsmen',
#  'Bakeries',
#  'Balloon Services',
#  'Bangladeshi',
#  'Bankruptcy Law',
#  'Banks & Credit Unions',
#  'Bar Crawl',
#  'Barbeque',
#  'Barbers',
#  'Barre Classes',
#  'Bars',
#  'Bartenders',
#  'Bartending Schools',
#  'Baseball Fields',
#  'Basketball Courts',
#  'Basque',
#  'Battery Stores',
#  'Batting Cages',
#  'Beach Bars',
#  'Beach Equipment Rentals',
#  'Beaches',
#  'Beauty & Spas',
#  'Bed & Breakfast',
#  'Beer',
#  'Beer Bar',
#  'Beer Garden',
#  'Beer Gardens',
#  'Beer Tours',
#  'Behavior Analysts',
#  'Belgian',
#  'Bespoke Clothing',
#  'Beverage Store',
#  'Bicycles',
#  'Bike Parking',
#  'Bike Rentals',
#  'Bike Repair',
#  'Bike Repair/Maintenance',
#  'Bike Sharing',
#  'Bike Shop',
#  'Bike tours',
#  'Bikes',
#  'Billing Services',
#  'Bingo Halls',
#  'Biohazard Cleanup',
#  'Bird Shops',
#  'Bistros',
#  'Blood & Plasma Donation Centers',
#  'Blow Dry/Out Services',
#  'Boat Charters',
#  'Boat Dealers',
#  'Boat Parts & Supplies',
#  'Boat Repair',
#  'Boat Tours',
#  'Boating',
#  'Bocce Ball',
#  'Body Contouring',
#  'Body Shops',
#  'Bookbinding',
#  'Bookkeepers',
#  'Books',
#  'Bookstores',
#  'Boot Camps',
#  'Botanical Gardens',
#  'Boudoir Photography',
#  'Bounce House Rentals',
#  'Bowling',
#  'Boxing',
#  'Brasseries',
#  'Brazilian',
#  'Brazilian Jiu-jitsu',
#  'Breakfast & Brunch',
#  'Breweries',
#  'Brewing Supplies',
#  'Brewpubs',
#  'Bridal',
#  'British',
#  'Bubble Soccer',
#  'Bubble Tea',
#  'Buddhist Temples',
#  'Buffets',
#  'Building Supplies',
#  'Bungee Jumping',
#  'Burgers',
#  'Burmese',
#  'Bus Rental',
#  'Bus Stations',
#  'Bus Tours',
#  'Buses',
#  'Business Consulting',
#  'Business Financing',
#  'Business Law',
#  'Butcher',
#  'CPR Classes',
#  'CSA',
#  'Cabaret',
#  'Cabinetry',
#  'Cafes',
#  'Cafeteria',
#  'Cajun/Creole',
#  'Calabrian',
#  'Calligraphy',
#  'Cambodian',
#  'Campgrounds',
#  'Candle Stores',
#  'Candy Stores',
#  'Cannabis Clinics',
#  'Cannabis Collective',
#  'Cannabis Dispensaries',
#  'Cannabis Tours',
#  'Cantonese',
#  'Car Auctions',
#  'Car Brokers',
#  'Car Buyers',
#  'Car Dealers',
#  'Car Inspectors',
#  'Car Rental',
#  'Car Share Services',
#  'Car Stereo Installation',
#  'Car Wash',
#  'Car Window Tinting',
#  'Cardio Classes',
#  'Cardiologists',
#  'Cards & Stationery',
#  'Career Counseling',
#  'Caribbean',
#  'Caricatures',
#  'Carousels',
#  'Carpenters',
#  'Carpet Cleaning',
#  'Carpet Dyeing',
#  'Carpet Installation',
#  'Carpeting',
#  'Casinos',
#  'Catalan',
#  'Caterers',
#  'Ceremonial Clothing',
#  'Challenge Courses',
#  'Champagne Bars',
#  'Check Cashing/Pay-day Loans',
#  'Cheerleading',
#  'Cheese Shops',
#  'Cheese Tasting Classes',
#  'Cheesesteaks',
#  'Chicken Shop',
#  'Chicken Wings',
#  'Child Care & Day Care',
#  'Childbirth Education',
#  'Childproofing',
#  "Children's Clothing",
#  "Children's Museums",
#  'Chimney Cakes',
#  'Chimney Sweeps',
#  'Chinese',
#  'Chinese Martial Arts',
#  'Chiropractors',
#  'Chocolatiers & Shops',
#  'Christmas Markets',
#  'Christmas Trees',
#  'Churches',
#  'Cideries',
#  'Cigar Bars',
#  'Cinema',
#  'Circuit Training Gyms',
#  'Civic Center',
#  'Climbing',
#  'Clock Repair',
#  'Clothing Rental',
#  'Clowns',
#  'Club Crawl',
#  'Cocktail Bars',
#  'Coffee & Tea',
#  'Coffee & Tea Supplies',
#  'Coffee Roasteries',
#  'Coffeeshops',
#  'College Counseling',
#  'Colleges & Universities',
#  'Colombian',
#  'Colonics',
#  'Comedy Clubs',
#  'Comfort Food',
#  'Comic Books',
#  'Commercial Real Estate',
#  'Commercial Truck Dealers',
#  'Commercial Truck Repair',
#  'Commissioned Artists',
#  'Community Centers',
#  'Community Gardens',
#  'Community Service/Non-Profit',
#  'Computers',
#  'Concept Shops',
#  'Concierge Medicine',
#  'Condominiums',
#  'Consumer Law',
#  'Contract Law',
#  'Contractors',
#  'Convenience Stores',
#  'Conveyor Belt Sushi',
#  'Cooking Classes',
#  'Cooking Schools',
#  'Cosmetic Dentists',
#  'Cosmetic Surgeons',
#  'Cosmetics & Beauty Supply',
#  'Cosmetology Schools',
#  'Costumes',
#  'Counseling & Mental Health',
#  'Countertop Installation',
#  'Country Clubs',
#  'Country Dance Halls',
#  'Couriers & Delivery Services',
#  'Court Reporters',
#  'Courthouses',
#  'Crane Services',
#  'Cremation Services',
#  'Creperies',
#  'Criminal Defense Law',
#  'Crisis Pregnancy Centers',
#  'Cryotherapy',
#  'Cuban',
#  'Cultural Center',
#  'Cupcakes',
#  'Currency Exchange',
#  'Custom Cakes',
#  'Customized Merchandise',
#  'Customs Brokers',
#  'Cycling Classes',
#  'Czech',
#  'DIY Auto Shop',
#  'DJs',
#  'DUI Law',
#  'Damage Restoration',
#  'Dance Clubs',
#  'Dance Schools',
#  'Dance Studios',
#  'Dance Wear',
#  'Data Recovery',
#  'Day Camps',
#  'Day Spas',
#  'Debt Relief Services',
#  'Decks & Railing',
#  'Delicatessen',
#  'Delis',
#  'Demolition Services',
#  'Dental Hygienists',
#  'Dentists',
#  'Department Stores',
#  'Departments of Motor Vehicles',
#  'Dermatologists',
#  'Desserts',
#  'Diagnostic Imaging',
#  'Diagnostic Services',
#  'Dialysis Clinics',
#  'Diamond Buyers',
#  'Dietitians',
#  'Digitizing Services',
#  'Dim Sum',
#  'Diners',
#  'Dinner Theater',
#  'Disability Law',
#  'Disc Golf',
#  'Discount Store',
#  'Distilleries',
#  'Dive Bars',
#  'Dive Shops',
#  'Diving',
#  'Divorce & Family Law',
#  'Do-It-Yourself Food',
#  'Doctors',
#  'Dog Parks',
#  'Dog Walkers',
#  'Dominican',
#  'Donation Center',
#  'Donuts',
#  'Door Sales/Installation',
#  'Doulas',
#  'Drama Schools',
#  'Drive-In Theater',
#  'Drive-Thru Bars',
#  'Driving Schools',
#  'Drones',
#  'Drugstores',
#  'Dry Cleaning',
#  'Dry Cleaning & Laundry',
#  'Drywall Installation & Repair',
#  'Dumpster Rental',
#  'Duplication Services',
#  'Duty-Free Shops',
#  'EV Charging Stations',
#  'Ear Nose & Throat',
#  'Eatertainment',
#  'Editorial Services',
#  'Education',
#  'Educational Services',
#  'Egyptian',
#  'Elder Care Planning',
#  'Elder Law',
#  'Electricians',
#  'Electricity Suppliers',
#  'Electronics',
#  'Electronics Repair',
#  'Elementary Schools',
#  'Embassy',
#  'Embroidery & Crochet',
#  'Emergency Medicine',
#  'Emergency Pet Hospital',
#  'Emergency Rooms',
#  'Empanadas',
#  'Employment Agencies',
#  'Employment Law',
#  'Endocrinologists',
#  'Endodontists',
#  'Engraving',
#  'Entertainment Law',
#  'Environmental Abatement',
#  'Environmental Testing',
#  'Eritrean',
#  'Escape Games',
#  'Estate Liquidation',
#  'Estate Planning Law',
#  'Estheticians',
#  'Ethical Grocery',
#  'Ethiopian',
#  'Ethnic Food',
#  'Ethnic Grocery',
#  'Event Photography',
#  'Event Planning & Services',
#  'Excavation Services',
#  'Eyebrow Services',
#  'Eyelash Service',
#  'Eyewear & Opticians',
#  'Fabric Stores',
#  'Face Painting',
#  'Falafel',
#  'Family Practice',
#  'Farm Equipment Repair',
#  'Farmers Market',
#  'Farming Equipment',
#  'Farms',
#  'Fashion',
#  'Fast Food',
#  'Fences & Gates',
#  'Feng Shui',
#  'Fertility',
#  'Festivals',
#  'Filipino',
#  'Financial Advising',
#  'Financial Services',
#  'Fingerprinting',
#  'Fire Departments',
#  'Fire Protection Services',
#  'Firearm Training',
#  'Fireplace Services',
#  'Firewood',
#  'Fireworks',
#  'First Aid Classes',
#  'Fish & Chips',
#  'Fishing',
#  'Fitness & Instruction',
#  'Fitness/Exercise Equipment',
#  'Flea Markets',
#  'Flight Instruction',
#  'Float Spa',
#  'Flooring',
#  'Floral Designers',
#  'Florists',
#  'Flowers',
#  'Flowers & Gifts',
#  'Flyboarding',
#  'Fondue',
#  'Food',
#  'Food Banks',
#  'Food Court',
#  'Food Delivery Services',
#  'Food Safety Training',
#  'Food Stands',
#  'Food Tours',
#  'Food Trucks',
#  'Formal Wear',
#  'Foundation Repair',
#  'Framing',
#  'Free Diving',
#  'French',
#  'Fruits & Veggies',
#  'Fuel Docks',
#  'Funeral Services & Cemeteries',
#  'Fur Clothing',
#  'Furniture Assembly',
#  'Furniture Rental',
#  'Furniture Repair',
#  'Furniture Reupholstery',
#  'Furniture Stores',
#  'Game Meat',
#  'Game Truck Rental',
#  'Garage Door Services',
#  'Gardeners',
#  'Gas Stations',
#  'Gastroenterologist',
#  'Gastropubs',
#  'Gay Bars',
#  'Gelato',
#  'Gemstones & Minerals',
#  'General Dentistry',
#  'General Festivals',
#  'General Litigation',
#  'Generator Installation/Repair',
#  'Geneticists',
#  'German',
#  'Gerontologists',
#  'Gift Shops',
#  'Glass & Mirrors',
#  'Glass Blowing',
#  'Gluten-Free',
#  'Go Karts',
#  'Gold Buyers',
#  'Golf',
#  'Golf Cart Dealers',
#  'Golf Cart Rentals',
#  'Golf Equipment',
#  'Golf Equipment Shops',
#  'Golf Lessons',
#  'Graphic Design',
#  'Greek',
#  'Grill Services',
#  'Grilling Equipment',
#  'Grocery',
#  'Grout Services',
#  'Guamanian',
#  'Guest Houses',
#  'Guitar Stores',
#  'Gun/Rifle Ranges',
#  'Guns & Ammo',
#  'Gunsmith',
#  'Gutter Services',
#  'Gymnastics',
#  'Gyms',
#  'Habilitative Services',
#  'Hainan',
#  'Hair Extensions',
#  'Hair Loss Centers',
#  'Hair Removal',
#  'Hair Salons',
#  'Hair Stylists',
#  'Halal',
#  'Halfway Houses',
#  'Halotherapy',
#  'Handyman',
#  'Hardware Stores',
#  'Hats',
#  'Haunted Houses',
#  'Hawaiian',
#  'Hazardous Waste Disposal',
#  'Head Shops',
#  'Health & Medical',
#  'Health Coach',
#  'Health Insurance Offices',
#  'Health Markets',
#  'Health Retreats',
#  'Hearing Aid Providers',
#  'Hearing Aids',
#  'Heating & Air Conditioning/HVAC',
#  'Henna Artists',
#  'Hepatologists',
#  'Herbal Shops',
#  'Herbs & Spices',
#  'High Fidelity Audio Equipment',
#  'Hiking',
#  'Himalayan/Nepalese',
#  'Hindu Temples',
#  'Historical Tours',
#  'Hobby Shops',
#  'Hockey Equipment',
#  'Holiday Decorating Services',
#  'Holiday Decorations',
#  'Holistic Animal Care',
#  'Home & Garden',
#  'Home & Rental Insurance',
#  'Home Automation',
#  'Home Cleaning',
#  'Home Decor',
#  'Home Developers',
#  'Home Energy Auditors',
#  'Home Health Care',
#  'Home Inspectors',
#  'Home Network Installation',
#  'Home Organization',
#  'Home Services',
#  'Home Staging',
#  'Home Theatre Installation',
#  'Home Window Tinting',
#  'Homeless Shelters',
#  'Homeopathic',
#  'Homeowner Association',
#  'Honduran',
#  'Honey',
#  'Hong Kong Style Cafe',
#  'Hookah Bars',
#  'Horse Boarding',
#  'Horse Equipment Shops',
#  'Horse Racing',
#  'Horseback Riding',
#  'Hospice',
#  'Hospitals',
#  'Hostels',
#  'Hot Air Balloons',
#  'Hot Dogs',
#  'Hot Pot',
#  'Hot Tub & Pool',
#  'Hotel bar',
#  'Hotels',
#  'Hotels & Travel',
#  'House Sitters',
#  'Hungarian',
#  'Hunting & Fishing Supplies',
#  'Hybrid Car Repair',
#  'Hydro-jetting',
#  'Hydroponics',
#  'Hydrotherapy',
#  'Hypnosis/Hypnotherapy',
#  'IP & Internet Law',
#  'IT Services & Computer Repair',
#  'IV Hydration',
#  'Iberian',
#  'Ice Cream & Frozen Yogurt',
#  'Ice Delivery',
#  'Immigration Law',
#  'Immunodermatologists',
#  'Imported Food',
#  'Indian',
#  'Indonesian',
#  'Indoor Landscaping',
#  'Indoor Playcentre',
#  'Infectious Disease Specialists',
#  'Installment Loans',
#  'Insulation Installation',
#  'Insurance',
#  'Interior Design',
#  'Interlock Systems',
#  'Internal Medicine',
#  'International Grocery',
#  'Internet Cafes',
#  'Internet Service Providers',
#  'Interval Training Gyms',
#  'Investing',
#  'Irish',
#  'Irish Pub',
#  'Irrigation',
#  'Italian',
#  'Izakaya',
#  'Jails & Prisons',
#  'Japanese',
#  'Japanese Curry',
#  'Jazz & Blues',
#  'Jet Skis',
#  'Jewelry',
#  'Jewelry Repair',
#  'Juice Bars & Smoothies',
#  'Junk Removal & Hauling',
#  'Junkyards',
#  'Karaoke',
#  'Karate',
#  'Kebab',
#  'Keys & Locksmiths',
#  'Kickboxing',
#  'Kids Activities',
#  'Kids Hair Salons',
#  'Kiosk',
#  'Kitchen & Bath',
#  'Kitchen Incubators',
#  'Kitchen Supplies',
#  'Knife Sharpening',
#  'Knitting Supplies',
#  'Kombucha',
#  'Korean',
#  'Kosher',
#  'LAN Centers',
#  'Laboratory Testing',
#  'Lactation Services',
#  'Lakes',
#  'Land Surveying',
#  'Landmarks & Historical Buildings',
#  'Landscape Architects',
#  'Landscaping',
#  'Language Schools',
#  'Laotian',
#  'Laser Eye Surgery/Lasik',
#  'Laser Hair Removal',
#  'Laser Tag',
#  'Latin American',
#  'Laundromat',
#  'Laundry Services',
#  'Lawn Services',
#  'Lawyers',
#  'Leather Goods',
#  'Lebanese',
#  'Legal Services',
#  'Leisure Centers',
#  'Libraries',
#  'Lice Services',
#  'Life Coach',
#  'Life Insurance',
#  'Lighting Fixtures & Equipment',
#  'Lighting Stores',
#  'Limos',
#  'Linens',
#  'Lingerie',
#  'Live/Raw Food',
#  'Livestock Feed & Supply',
#  'Local Fish Stores',
#  'Local Flavor',
#  'Local Services',
#  'Lounges',
#  'Luggage',
#  'Luggage Storage',
#  'Macarons',
#  'Machine & Tool Rental',
#  'Machine Shops',
#  'Magicians',
#  'Mags',
#  'Mailbox Centers',
#  'Makerspaces',
#  'Makeup Artists',
#  'Malaysian',
#  'Marinas',
#  'Market Stalls',
#  'Marketing',
#  'Martial Arts',
#  'Masonry/Concrete',
#  'Mass Media',
#  'Massage',
#  'Massage Schools',
#  'Massage Therapy',
#  'Matchmakers',
#  'Maternity Wear',
#  'Mattresses',
#  'Meaderies',
#  'Meat Shops',
#  'Mediators',
#  'Medical Cannabis Referrals',
#  'Medical Centers',
#  'Medical Foot Care',
#  'Medical Law',
#  'Medical Spas',
#  'Medical Supplies',
#  'Medical Transportation',
#  'Meditation Centers',
#  'Mediterranean',
#  'Memory Care',
#  "Men's Clothing",
#  "Men's Hair Salons",
#  'Metal Fabricators',
#  'Metro Stations',
#  'Mexican',
#  'Middle Eastern',
#  'Middle Schools & High Schools',
#  'Midwives',
#  'Military Surplus',
#  'Mini Golf',
#  'Misting System Services',
#  'Mobile Dent Repair',
#  'Mobile Home Dealers',
#  'Mobile Home Parks',
#  'Mobile Home Repair',
#  'Mobile Phone Accessories',
#  'Mobile Phone Repair',
#  'Mobile Phones',
#  'Mobility Equipment Sales & Services',
#  'Modern European',
#  'Mongolian',
#  'Montessori Schools',
#  'Moroccan',
#  'Mortgage Brokers',
#  'Mortgage Lenders',
#  'Mortuary Services',
#  'Mosques',
#  'Motorcycle Dealers',
#  'Motorcycle Gear',
#  'Motorcycle Parts & Supplies',
#  'Motorcycle Rental',
#  'Motorcycle Repair',
#  'Motorsport Vehicle Dealers',
#  'Motorsport Vehicle Repairs',
#  'Mountain Biking',
#  'Movers',
#  'Muay Thai',
#  'Municipality',
#  'Museums',
#  'Music & DVDs',
#  'Music & Video',
#  'Music Production Services',
#  'Music Venues',
#  'Musical Instrument Services',
#  'Musical Instruments & Teachers',
#  'Musicians',
#  'Nail Salons',
#  'Nail Technicians',
#  'Nanny Services',
#  'Natural Gas Suppliers',
#  'Naturopathic/Holistic',
#  'Nephrologists',
#  'Neurologist',
#  'Neuropathologists',
#  'Neurotologists',
#  'New Mexican Cuisine',
#  'Newspapers & Magazines',
#  'Nicaraguan',
#  'Nightlife',
#  'Noodles',
#  'Notaries',
#  'Nudist',
#  'Nurse Practitioner',
#  'Nurseries & Gardening',
#  'Nursing Schools',
#  'Nutritionists',
#  'Oaxacan',
#  'Observatories',
#  'Obstetricians & Gynecologists',
#  'Occupational Therapy',
#  'Office Cleaning',
#  'Office Equipment',
#  'Officiants',
#  'Oil Change Stations',
#  'Olive Oil',
#  'Oncologist',
#  'Opera & Ballet',
#  'Ophthalmologists',
#  'Optometrists',
#  'Oral Surgeons',
#  'Organic Stores',
#  'Orthodontists',
#  'Orthopedists',
#  'Orthotics',
#  'Osteopathic Physicians',
#  'Osteopaths',
#  'Otologists',
#  'Outdoor Furniture Stores',
#  'Outdoor Gear',
#  'Outdoor Movies',
#  'Outdoor Power Equipment Services',
#  'Outlet Stores',
#  'Oxygen Bars',
#  'Packing Services',
#  'Packing Supplies',
#  'Paddleboarding',
#  'Pain Management',
#  'Paint & Sip',
#  'Paint Stores',
#  'Paint-Your-Own Pottery',
#  'Paintball',
#  'Painters',
#  'Pakistani',
#  'Pan Asian',
#  'Pancakes',
#  'Paragliding',
#  'Parenting Classes',
#  'Parking',
#  'Parks',
#  'Party & Event Planning',
#  'Party Bike Rentals',
#  'Party Bus Rentals',
#  'Party Characters',
#  'Party Equipment Rentals',
#  'Party Supplies',
#  'Passport & Visa Services',
#  'Pasta Shops',
#  'Patent Law',
#  'Pathologists',
#  'Patio Coverings',
#  'Patisserie/Cake Shop',
#  'Pawn Shops',
#  'Payroll Services',
#  'Pediatric Dentists',
#  'Pediatricians',
#  'Pedicabs',
#  'Performing Arts',
#  'Perfume',
#  'Periodontists',
#  'Permanent Makeup',
#  'Persian/Iranian',
#  'Personal Assistants',
#  'Personal Care Services',
#  'Personal Chefs',
#  'Personal Injury Law',
#  'Personal Shopping',
#  'Peruvian',
#  'Pest Control',
#  'Pet Adoption',
#  'Pet Boarding',
#  'Pet Breeders',
#  'Pet Cremation Services',
#  'Pet Groomers',
#  'Pet Hospice',
#  'Pet Insurance',
#  'Pet Photography',
#  'Pet Services',
#  'Pet Sitting',
#  'Pet Stores',
#  'Pet Training',
#  'Pet Transportation',
#  'Pet Waste Removal',
#  'Pets',
#  'Petting Zoos',
#  'Pharmacy',
#  'Phlebologists',
#  'Photo Booth Rentals',
#  'Photographers',
#  'Photography Classes',
#  'Photography Stores & Services',
#  'Physical Therapy',
#  'Piano Bars',
#  'Piano Services',
#  'Piano Stores',
#  'Pick Your Own Farms',
#  'Pickleball',
#  'Piercing',
#  'Pilates',
#  'Pita',
#  'Pizza',
#  'Placenta Encapsulations',
#  'Planetarium',
#  'Plastic Surgeons',
#  'Playgrounds',
#  'Playsets',
#  'Plumbing',
#  'Plus Size Fashion',
#  'Podiatrists',
#  'Poke',
#  'Pole Dancing Classes',
#  'Police Departments',
#  'Polish',
#  'Polynesian',
#  'Pool & Billiards',
#  'Pool & Hot Tub Service',
#  'Pool Cleaners',
#  'Pool Halls',
#  'Pop-Up Restaurants',
#  'Pop-up Shops',
#  'Popcorn Shops',
#  'Portable Toilet Services',
#  'Portuguese',
#  'Post Offices',
#  'Poutineries',
#  'Powder Coating',
#  'Prenatal/Perinatal Care',
#  'Preschools',
#  'Pressure Washers',
#  'Pretzels',
#  'Preventive Medicine',
#  'Print Media',
#  'Printing Services',
#  'Private Investigation',
#  'Private Jet Charter',
#  'Private Schools',
#  'Private Tutors',
#  'Process Servers',
#  'Proctologists',
#  'Product Design',
#  'Professional Services',
#  'Professional Sports Teams',
#  'Propane',
#  'Property Management',
#  'Props',
#  'Prosthetics',
#  'Prosthodontists',
#  'Psychiatrists',
#  'Psychic Mediums',
#  'Psychics',
#  'Psychologists',
#  'Pub Food',
#  'Public Adjusters',
#  'Public Art',
#  'Public Markets',
#  'Public Relations',
#  'Public Services & Government',
#  'Public Transportation',
#  'Pubs',
#  'Puerto Rican',
#  'Pulmonologist',
#  'Pumpkin Patches',
#  'Qi Gong',
#  'RV Dealers',
#  'RV Parks',
#  'RV Rental',
#  'RV Repair',
#  'Race Tracks',
#  'Races & Competitions',
#  'Racing Experience',
#  'Radio Stations',
#  'Radiologists',
#  'Rafting/Kayaking',
#  'Ramen',
#  'Ranches',
#  'Real Estate',
#  'Real Estate Agents',
#  'Real Estate Law',
#  'Real Estate Photography',
#  'Real Estate Services',
#  'Recording & Rehearsal Studios',
#  'Recreation Centers',
#  'Recycling Center',
#  'Refinishing Services',
#  'Reflexology',
#  'Registration Services',
#  'Registry Office',
#  'Rehabilitation Center',
#  'Reiki',
#  'Religious Items',
#  'Religious Organizations',
#  ...]

# %%
categories_exploded.info()
categories_exploded.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 542936 entries, 0 to 124891
# Data columns (total 2 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   business_id  542936 non-null  object
#  1   categories   542936 non-null  object
# dtypes: object(2)
# memory usage: 12.4+ MB
#               business_id        categories
# 0  f9NumwFMBDn751xgFiRbNA       Active Life
# 0  f9NumwFMBDn751xgFiRbNA  Gun/Rifle Ranges
# 0  f9NumwFMBDn751xgFiRbNA       Guns & Ammo
# 0  f9NumwFMBDn751xgFiRbNA          Shopping
# 1  Yzvjg0SayhoZgCljUJRF9Q  Health & Medical

# %%
'''
# !pip3 install py_stringsimjoin
#!pip install python-Levenshtein
# !pip3 install py_stringmatching
#!pip install difflib
'''

# %%
'''import py_stringsimjoin as ssj
import py_stringmatching as sm
from Levenshtein import distance
from difflib import SequenceMatcher
'''

# %% [markdown]
# Let's see if we can find close matches for tags by using a Jaccard Join

# %%
# create our tokenizer
#tokenizer = sm.QgramTokenizer(qval= 3, return_set= True )

# %%
# Replace commas in all fields to not mess up the csv file

#We'll replace the wills, trusts, & probates field we just made with other &s
categories_exploded.replace('Wills, Trusts, & Probates', 'Wills & Trusts & Probates', inplace =True)

#Check for any more commas
print(categories_exploded[categories_exploded['categories'].str.contains(',')])
print(categories_exploded[categories_exploded['business_id'].str.contains(',')])
# Out:
# Empty DataFrame
# Columns: [business_id, categories]
# Index: []
# Empty DataFrame
# Columns: [business_id, categories]
# Index: []

# %%
categories_exploded[~categories_exploded['business_id'].isin(yelp_final['business_id'])]
# Out:
#                   business_id             categories
# 29837  LiQckUkfrmaU09DijHLLpQ           Martial Arts
# 29837  LiQckUkfrmaU09DijHLLpQ  Fitness & Instruction
# 29837  LiQckUkfrmaU09DijHLLpQ            Active Life
# 29837  LiQckUkfrmaU09DijHLLpQ              Taekwondo

# %%
categories_exploded.to_csv('yelp_categories.csv', index= False)

# %%
yelp_reduced[yelp_reduced['business_id'] == 'LiQckUkfrmaU09DijHLLpQ']
# Out:
#                   business_id name          city state  postal_code  \
# 29837  LiQckUkfrmaU09DijHLLpQ  NaN  Huntersville    NC      28078.0
#
#         latitude  longitude  stars  review_count  \
# 29837  35.383981 -80.786123    2.0             3
#
#                                               attributes  \
# 29837  {'GoodForKids': 'True', 'BusinessAcceptsCredit...
#
#                                                    hours
# 29837  {'Monday': '10:0-20:30', 'Tuesday': '10:0-20:3...
